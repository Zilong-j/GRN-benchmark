# %%
# %load_ext memory_profiler

# %% [markdown]
# ## 1. Preparation of individual input files in `data` folder
# After data processing with CellRanger, you need the following files:
# * RNA read count matrix ("Filtered feature barcode matrix MEX (DIR)")
# * ATAC reads ("ATAC Position-sorted alignments (BAM)")
# * Optionally or from other softwares: cell clustering (inside "Secondary analysis outputs (DIR)")

# %%
#Add path
import os
os.environ['PATH'] = os.path.expanduser('~/.conda/envs/dictys/bin') + ':' + os.environ['PATH']
print(os.getenv('PATH'))
# Out:
# /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/.conda/envs/dictys/bin:/opt/gridware/apps/gcc/R/4.3.2/bin:/opt/gridware/compilers/gcc/11.2.0/bin:/opt/gridware2/apps/binapps/anaconda3/2019.07/bin:/opt/gridware2/apps/binapps/anaconda3/2019.07/condabin:/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/.local/bin:/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/bin:/usr/share/Modules/bin:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin

# %%
# Removes CPU usage limit by some jupyter versions
import os
os.environ['KMP_AFFINITY'] = ''
#Create input data folder
current_path = os.getcwd()
print(current_path)
# Out:
# /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys

# %% [markdown]
# ### expression.tsv.gz
# Read count matrix of RNA-profiled cells in compressed tsv format. Downloaded and converted from "Filtered feature barcode matrix MEX (DIR)".

# %%
# %%bash
# cd ./data
# # Download expression data in mtx.gz format
# wget -q -o /dev/null https://cf.10xgenomics.com/samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.tar.gz
# tar xf pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.tar.gz
# rm pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.tar.gz
# # Convert from mtx.gz to tsv.gz format using helper script `expression_mtx.py`.
# dictys_helper expression_mtx.py filtered_feature_bc_matrix expression.tsv.gz
# rm -Rf filtered_feature_bc_matrix
# Out:
# WARNING:root:Skipped duplicate occurrence of gene names: TBCE,LINC01238,CYB561D2,MATR3,LINC01505,HSPA14,GOLGA8M,GGT1,ARMCX5-GPRASP2,TMSB15B

# %% [markdown]
# ### bams
# This folder contains one bam file for each cell with chromatin accessibility measurement. File name should be cell name. Downloaded and converted from "ATAC Position-sorted alignments (BAM)".

# %%
# %%bash
# set -eo pipefail
# cd ./data
# # Download chromatin accessibility reads in bam format
# wget --debug --progress=bar:force:noscroll -O bams.bam https://cf.10xgenomics.com/samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_atac_possorted_bam.bam
# Out:
# Setting --progress (progress) to bar:force:noscroll
# Setting --output-document (outputdocument) to bams.bam
# DEBUG output created by Wget 1.21.4 on linux-gnu.
#
# Reading HSTS entries from /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/.wget-hsts
# URI encoding = ‘UTF-8’
# --2024-07-18 23:47:43--  https://cf.10xgenomics.com/samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_atac_possorted_bam.bam
# Resolving cf.10xgenomics.com (cf.10xgenomics.com)... 104.18.1.173, 104.18.0.173, 2606:4700::6812:1ad, ...
# Caching cf.10xgenomics.com => 104.18.1.173 104.18.0.173 2606:4700::6812:1ad 2606:4700::6812:ad
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:443... connected.
# Created socket 4.
# Releasing 0x000055ae7779bcf0 (new refcount 1).
# Initiating SSL handshake.
# Handshake successful; connected socket 4 to SSL handle 0x000055ae7779d830
# certificate:
#   subject: CN=10xgenomics.com
#   issuer:  CN=E1,O=Let's Encrypt,C=US
# X509 certificate successfully verified and matches host cf.10xgenomics.com
#
# ---request begin---
# GET /samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_atac_possorted_bam.bam HTTP/1.1
# Host: cf.10xgenomics.com
# User-Agent: Wget/1.21.4
# Accept: */*
# Accept-Encoding: identity
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 200 OK
# Date: Thu, 18 Jul 2024 22:47:44 GMT
# Content-Type: binary/octet-stream
# Content-Length: 46894629363
# Connection: keep-alive
# last-modified: Sun, 06 Sep 2020 06:00:11 GMT
# etag: "9e641d777a04a1db59a9433820a2061a-5591"
# x-amz-storage-class: INTELLIGENT_TIERING
# x-amz-version-id: VfR90GBGWVLkI6Lq4DeewOIZt6IZp9Di
# accept-ranges: bytes
# x-cache: Miss from cloudfront
# via: 1.1 6bb8eb5712512d0233fdbd1d8dcf84b6.cloudfront.net (CloudFront)
# x-amz-cf-pop: LHR5-P5
# x-amz-cf-id: 0T9Cc99lQ-4_q1lRokGSeo0pEE_TABovPCuzgsKYhy-BHnXHE3nkjA==
# CF-Cache-Status: DYNAMIC
# Server: cloudflare
# CF-RAY: 8a5603e1ad36b101-MAN
#
# ---response end---
# 200 OK
# Registered socket 4 for persistent reuse.
# Length: 46894629363 (44G) [binary/octet-stream]
# Saving to: ‘bams.bam’
#
# bams.bam            100%[===================>]  43.67G  29.0MB/s    in 35m 6s
#
# 2024-07-19 00:22:50 (21.2 MB/s) - ‘bams.bam’ saved [46894629363/46894629363]

# %%
# %%bash
# set -eo pipefail
# cd ./data
# dictys_helper split_bam.sh bams.bam bams --section "CB:Z:" --ref_expression expression.tsv.gz
# rm bams.bam

# %% [markdown]
# ### subsets & subsets.txt
# * subsets.txt: Names of cell subsets. For each cell subset, a GRN is reconstructed.
# * subsets: Folder containing one subfolder for each cell subset as in `subsets.txt`. Each subfolder contains two files:
#     - names_rna.txt: Names of cells that belong to this subset and have transcriptome measurement
#     - names_atac.txt: Names of cells that belong to this subset and have chromatin accessibility measurement
#     - For joint measurements of RNA and ATAC, these two files should be identical in every folder.

# %%
# %%bash
# cd ./data
# wget -q -o /dev/null https://cf.10xgenomics.com/samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_analysis.tar.gz
# #Extract cell names for each cluster
# tar xf pbmc_granulocyte_sorted_10k_analysis.tar.gz
# mv analysis/clustering/gex/graphclust/clusters.csv clusters.csv
# rm -Rf pbmc_granulocyte_sorted_10k_analysis.tar.gz analysis

# %% [markdown]
# Finally, reformat clusters.csv for input:

# %%
# %%bash
# cd ./data
# subsets="$(tail -n +2 clusters.csv | awk -F , '{print $2}' | sort -u)"
# echo "$subsets" | awk '{print "Subset"$1}' > subsets.txt
# for x in $subsets; do
# 	mkdir -p "subsets/Subset$x"
# 	grep ",$x"'$' clusters.csv | awk -F , '{print $1}' > "subsets/Subset$x/names_rna.txt"
# 	# RNA and ATAC barcodes are the same for joint quantifications
# 	cp "subsets/Subset$x/names_rna.txt" "subsets/Subset$x/names_atac.txt"
# done
# rm clusters.csv

# %% [markdown]
# ### Other files
# Motif, reference genome, gene transcriptional start site

# %%
# %%bash
# cd ./data
#
# # Motifs (file motifs.motif)
# # from HOCOMOCO (https://hocomoco11.autosome.org/)
# wget -q -o /dev/null -O motifs.motif 'https://hocomoco11.autosome.org/final_bundle/hocomoco11/full/HUMAN/mono/HOCOMOCOv11_full_HUMAN_mono_homer_format_0.0001.motif'
# Out:
# Warning: skipped motif file because not found: rorc.motif

# %%
# !head -n 18 ./data/motifs.motif
# Out:
# >dKhGCGTGh	AHR_HUMAN.H11MO.0.B	3.3775000000000004
# 0.262728374765856	0.1227600511842322	0.362725638699551	0.25178593535036087
# 0.07633328991810645	0.08258130543118362	0.22593295481662123	0.6151524498340887
# 0.14450570038747923	0.28392173880411337	0.13815442099009081	0.4334181398183167
# 0.023935814057894068	0.016203821748029118	0.9253278681170539	0.03453249607702277
# 0.007919544273173793	0.953597675415874	0.017308392078009837	0.021174388232942286
# 0.02956192959210962	0.012890110758086997	0.9474192747166682	0.010128684933135217
# 0.007919544273173797	0.029561929592109615	0.012337825593096645	0.9501807005416201
# 0.007919544273173793	0.007919544273173793	0.9762413671804787	0.007919544273173793
# 0.27886589130660366	0.4285328543459993	0.10955683916661985	0.18304441518077724
# >hnnGGWWnddWWGGdbWh	AIRE_HUMAN.H11MO.0.C	5.64711
# 0.38551919443239085	0.2604245534178759	0.1353299124033618	0.21872633974637148
# 0.18745267949274294	0.18745267949274294	0.14575446582123766	0.4793401751932764
# 0.14575446582123777	0.14575446582123777	0.2083017863284958	0.5001892820290286
# 0.0623580384782284	0.020659824806723626	0.8337749914010671	0.08320714531398087
# 0.020659824806723633	0.020659824806723633	0.7712276708938095	0.18745267949274314
# 0.3125473205072573	0.062358038478228406	0.04150893164247602	0.5835857093720382
# 0.37509464101451423	0.10405625214973326	0.04150893164247601	0.4793401751932766

# %%
# %%bash
# cd ./data
# # Reference genome (folder genome)
# # Download genome from HOMER
# dictys_helper genome_homer.sh hg38 genome
# Out:
# Process is interrupted.

# %%
# %%bash
# ls -h1s ./data/genome | head
# Out:
# total 5.3G
# 113K annotations
# 153K chrom.sizes
# 3.7G genome.fa
# 4.2M hg38.aug
#  51M hg38.basic.annotation
# 822M hg38.full.annotation
# 641K hg38.miRNA
# 616M hg38.repeats
#  32M hg38.rna

# %%
# %%bash
# cd ./data
# # Bed file for TSS (file gene.bed)
# # Download gtf file from ensembl
# wget -q -o /dev/null -O gene.gtf.gz http://ftp.ensembl.org/pub/release-107/gtf/homo_sapiens/Homo_sapiens.GRCh38.107.gtf.gz
# gunzip gene.gtf.gz
# # Convert to bed
# dictys_helper gene_gtf.sh gene.gtf gene.bed
# rm gene.gtf

# %%
# !head ./data/gene.bed
# Out:
# chr1	11869	14409	DDX11L1	.	+
# chr1	14404	29570	WASH7P	.	-
# chr1	17369	17436	MIR6859-1	.	-
# chr1	29554	31109	MIR1302-2HG	.	+
# chr1	30366	30503	MIR1302-2	.	+
# chr1	34554	36081	FAM138A	.	-
# chr1	52473	53312	OR4G4P	.	+
# chr1	57598	64116	OR4G11P	.	+
# chr1	65419	71585	OR4F5	.	+
# chr1	131025	134836	CICP27	.	+

# %% [markdown]
# ### Clean up

# %%
# !rm -Rf ./data/filtered_feature_bc_matrix

# %% [markdown]
# ## 2. Network inference configuration
# ### Generate configurations
# Please adjust them for your own machine and dataset

# %%
pwd
# Out:
# '/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys'

# %%
# %%bash
# # Generate configuration template
# rm -Rf ./makefiles
# mkdir ./makefiles
# cd ./makefiles
# dictys_helper makefile_template.sh common.mk config.mk env_none.mk static.mk
#
# # Update configurations, such as:
# # DEVICE: pytorch device, e.g. cpu, cuda:0. If you do not have a GPU, use 'cpu' and expect LONG computing time.
# # GENOME_MACS2: effective genome size for macs2. See https://deeptools.readthedocs.io/en/develop/content/feature/effectiveGenomeSize.html
# # JOINT: whether dataset is joint profiling of RNA and ATAC.
# # Other configurations include quality control thresholds, number of threads in each job, number of hidden confounders, etc.
# # They can be obtained in the full-multiome tutorial.
# dictys_helper makefile_update.py ../makefiles/config.mk '{"DEVICE": "cpu", "GENOME_MACS2": "hs", "JOINT": "1"}'

# %%
# !cat ./makefiles/config.mk
# Out:
# # Lingfei Wang, 2022. All rights reserved.
# #This file contains parameters for whole run and individual steps to be edited for your dataset
# #This file should be edited to configure the run
# #This file should NOT be directly used for any run with `makefile -f`
#
# ############################################################
# # Run environment settings
# ############################################################
# #Which environment to use, corresponding to env_$(ENVMODE).mk file
# ENVMODE=none
# #Maximum number of CPU threads for each job
# #This is only nominated and passed through to other softwares without any guarantee.
# NTH=4
# #Device name for pyro/pytorch
# #Note: cuda devices other than cuda:0 could be incompatible with singularity environment
# DEVICE=cpu
#
# ############################################################
# # Dataset settings
# ############################################################
#
# #Genome size for Macs2, accept shortcuts like mm & hs
# GENOME_MACS2=hs
# #Whether dataset is joint profiling of RNA & ATAC of same cell. Separate measurements of two modalities in different cells: 0. Joint measurements: 1.
# JOINT=1
#
# #######################################################################################
# # Parameters of individual steps shared by cell-type specific and dynamic GRN inference
# #######################################################################################
#
# PARAMS-PREPROC-QC_READS:=50 10 0 200 100 0
# PARAMS-CHROMATIN-MACS2:=$(GENOME_MACS2)
# PARAMS-CHROMATIN-BINLINKING:=20
# KPARAMS-PREPROC-SELECTSC_RNA:=
# KPARAMS-PREPROC-QC_READS:=
# KPARAMS-PREPROC-SELECTSC_ATAC:=
# KPARAMS-CHROMATIN-MACS2:=--nth $(NTH)
# KPARAMS-CHROMATIN-WELLINGTON:=--nth $(NTH)
# KPARAMS-CHROMATIN-HOMER:=--nth $(NTH)
# KPARAMS-CHROMATIN-BINDING:=
# KPARAMS-CHROMATIN-TSSDIST:=
# KPARAMS-CHROMATIN-LINKING:=
# KPARAMS-CHROMATIN-BINLINKING:=
# KPARAMS-NETWORK-RECONSTRUCT:=--device $(DEVICE) --nth $(NTH)
# KPARAMS-NETWORK-INDIRECT:=--nth $(NTH)
# KPARAMS-NETWORK-NORMALIZE:=--nth $(NTH)
# KPARAMS-NETWORK-TOFILE:=$(KPARAMS-NETWORK-TOFILE_EXTRA)
#
# #######################################################################################
# # Parameters of individual steps only in dynamic GRN inference
# #######################################################################################
#
# PARAMS-DYNAMIC-SUBSETS_RNA=1000 875 0.05
# PARAMS-DYNAMIC-SUBSETS_ATAC=$(firstword $(PARAMS-DYNAMIC-SUBSETS_RNA))

# %% [markdown]
# ### Validate input data

# %%
# %%bash
# /usr/bin/time -v cd . &&  /usr/bin/time -v dictys_helper makefile_check.py
# Out:
# 	Command being timed: "cd ."
# 	User time (seconds): 0.00
# 	System time (seconds): 0.00
# 	Percent of CPU this job got: 33%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 0:00.00
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 3328
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 0
# 	Minor (reclaiming a frame) page faults: 189
# 	Voluntary context switches: 2
# 	Involuntary context switches: 0
# 	Swaps: 0
# 	File system inputs: 0
# 	File system outputs: 0
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0
# WARNING:root:Chromosomes not found in reference genome: chrGL000194.1,chrMT
# WARNING:root:Cannot find dynamic.mk or traj_node.h5. Skipping dynamic network inference checks.
# Joint profile: True
# Found 11909 cells with RNA profile
# Found 24036 genes with RNA profile
# Found 11909 cells with ATAC profile
# Found 769 motifs
# Found 678 TFs
# Found 461 TFs in current dataset
# Missing 217 TFs in current dataset: ANDR,AP2A,AP2B,AP2C,AP2D,ARI3A,ARI5B,ATF6A,BARH1,BARH2,BC11A,BHA15,BHE22,BHE23,BHE40,BHE41,BMAL1,BRAC,BSH,COE1,COT1,COT2,CR3L1,CR3L2,ERR1,ERR2,ERR3,EVI1,GCR,HEN1,HMBX1,HME1,HME2,HNF6,HTF4,HXA1,HXA10,HXA11,HXA13,HXA2,HXA5,HXA7,HXA9,HXB1,HXB13,HXB2,HXB3,HXB4,HXB6,HXB7,HXB8,HXC10,HXC11,HXC12,HXC13,HXC6,HXC8,HXC9,HXD10,HXD11,HXD12,HXD13,HXD3,HXD4,HXD8,HXD9,ITF2,KAISO,MCR,MGAP,MLXPL,MYBA,MYBB,NDF1,NDF2,NF2L1,NF2L2,NFAC1,NFAC2,NFAC3,NFAC4,NGN2,NKX21,NKX22,NKX23,NKX25,NKX28,NKX31,NKX32,NKX61,NKX62,ONEC2,ONEC3,OZF,P53,P5F1B,P63,P73,PEBB,PHX2A,PHX2B,PIT1,PKNX1,PLAL1,PO2F1,PO2F2,PO2F3,PO3F1,PO3F2,PO3F3,PO3F4,PO4F1,PO4F2,PO4F3,PO5F1,PO6F1,PO6F2,PRD14,PRGR,RHXF1,RORG,RX,SMCA1,SMCA5,SRBP1,SRBP2,STA5A,STA5B,STF1,SUH,TF2LX,TF65,TF7L1,TF7L2,TFE2,THA,THA11,THB,TWST1,TYY1,TYY2,UBIP1,UNC4,Z324A,Z354A,ZBT14,ZBT17,ZBT18,ZBT48,ZBT49,ZBT7A,ZBT7B,ZEP1,ZEP2,ZF64A,ZKSC1,ZKSC3,ZN121,ZN134,ZN136,ZN140,ZN143,ZN148,ZN214,ZN219,ZN232,ZN250,ZN257,ZN260,ZN263,ZN264,ZN274,ZN281,ZN282,ZN317,ZN320,ZN322,ZN329,ZN331,ZN333,ZN335,ZN341,ZN350,ZN382,ZN384,ZN394,ZN410,ZN418,ZN423,ZN436,ZN449,ZN467,ZN490,ZN502,ZN524,ZN528,ZN547,ZN549,ZN554,ZN563,ZN582,ZN586,ZN589,ZN652,ZN667,ZN680,ZN708,ZN713,ZN740,ZN768,ZN770,ZN784,ZN816,ZSC16,ZSC22,ZSC31,ZSCA4
# Found 23533 genes with TSS information
# 	Command being timed: "dictys_helper makefile_check.py"
# 	User time (seconds): 20.91
# 	System time (seconds): 3.98
# 	Percent of CPU this job got: 53%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 0:46.11
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 7925516
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 0
# 	Minor (reclaiming a frame) page faults: 2119390
# 	Voluntary context switches: 69043
# 	Involuntary context switches: 561
# 	Swaps: 0
# 	File system inputs: 6440144
# 	File system outputs: 0
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %% [markdown]
# ## 3. Network inference

# %%
import os
print(os.cpu_count())
# Out:
# 32

# %%
# %memit
# Out:
# peak memory: 65.46 MiB, increment: 0.25 MiB

# %%
# %%bash
# /usr/bin/time -v cd .;
# /usr/bin/time -v dictys_helper network_inference.sh -j 32 -J 1 static
# Out:
# 	Command being timed: "cd ."
# 	User time (seconds): 0.00
# 	System time (seconds): 0.00
# 	Percent of CPU this job got: 100%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 0:00.00
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 3328
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 0
# 	Minor (reclaiming a frame) page faults: 188
# 	Voluntary context switches: 1
# 	Involuntary context switches: 0
# 	Swaps: 0
# 	File system inputs: 0
# 	File system outputs: 0
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0
# mkdir -p tmp_static/Subset1/
# cp data/subsets/Subset1/names_rna.txt tmp_static/Subset1/names_rna.txt
# mkdir -p tmp_static/Subset10/
# mkdir -p tmp_static/Subset11/
# cp data/subsets/Subset10/names_rna.txt tmp_static/Subset10/names_rna.txt
# cp data/subsets/Subset11/names_rna.txt tmp_static/Subset11/names_rna.txt
# mkdir -p tmp_static/Subset12/
# cp data/subsets/Subset12/names_rna.txt tmp_static/Subset12/names_rna.txt
# mkdir -p tmp_static/Subset13/
# cp data/subsets/Subset13/names_rna.txt tmp_static/Subset13/names_rna.txt
# mkdir -p tmp_static/Subset14/
# cp data/subsets/Subset14/names_rna.txt tmp_static/Subset14/names_rna.txt
# mkdir -p tmp_static/Subset15/
# cp data/subsets/Subset15/names_rna.txt tmp_static/Subset15/names_rna.txt
# mkdir -p tmp_static/Subset16/
# mkdir -p tmp_static/Subset17/
# cp data/subsets/Subset16/names_rna.txt tmp_static/Subset16/names_rna.txt
# cp data/subsets/Subset17/names_rna.txt tmp_static/Subset17/names_rna.txt
# mkdir -p tmp_static/Subset2/
# mkdir -p tmp_static/Subset3/
# cp data/subsets/Subset2/names_rna.txt tmp_static/Subset2/names_rna.txt
# cp data/subsets/Subset3/names_rna.txt tmp_static/Subset3/names_rna.txt
# mkdir -p tmp_static/Subset4/
# cp data/subsets/Subset4/names_rna.txt tmp_static/Subset4/names_rna.txt
# mkdir -p tmp_static/Subset5/
# cp data/subsets/Subset5/names_rna.txt tmp_static/Subset5/names_rna.txt
# mkdir -p tmp_static/Subset6/
# cp data/subsets/Subset6/names_rna.txt tmp_static/Subset6/names_rna.txt
# mkdir -p tmp_static/Subset7/
# cp data/subsets/Subset7/names_rna.txt tmp_static/Subset7/names_rna.txt
# mkdir -p tmp_static/Subset8/
# cp data/subsets/Subset8/names_rna.txt tmp_static/Subset8/names_rna.txt
# mkdir -p tmp_static/Subset9/
# cp data/subsets/Subset9/names_rna.txt tmp_static/Subset9/names_rna.txt
# cp tmp_static/Subset1/names_rna.txt tmp_static/Subset1/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset1/names_rna.txt tmp_static/Subset1/expression0.tsv.gz
# cp tmp_static/Subset10/names_rna.txt tmp_static/Subset10/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset10/names_rna.txt tmp_static/Subset10/expression0.tsv.gz
# cp tmp_static/Subset11/names_rna.txt tmp_static/Subset11/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset11/names_rna.txt tmp_static/Subset11/expression0.tsv.gz
# cp tmp_static/Subset12/names_rna.txt tmp_static/Subset12/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset12/names_rna.txt tmp_static/Subset12/expression0.tsv.gz
# cp tmp_static/Subset13/names_rna.txt tmp_static/Subset13/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset13/names_rna.txt tmp_static/Subset13/expression0.tsv.gz
# cp tmp_static/Subset14/names_rna.txt tmp_static/Subset14/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset14/names_rna.txt tmp_static/Subset14/expression0.tsv.gz
# cp tmp_static/Subset15/names_rna.txt tmp_static/Subset15/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset15/names_rna.txt tmp_static/Subset15/expression0.tsv.gz
# cp tmp_static/Subset16/names_rna.txt tmp_static/Subset16/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset16/names_rna.txt tmp_static/Subset16/expression0.tsv.gz
# cp tmp_static/Subset17/names_rna.txt tmp_static/Subset17/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset17/names_rna.txt tmp_static/Subset17/expression0.tsv.gz
# cp tmp_static/Subset2/names_rna.txt tmp_static/Subset2/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset2/names_rna.txt tmp_static/Subset2/expression0.tsv.gz
# cp tmp_static/Subset3/names_rna.txt tmp_static/Subset3/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset3/names_rna.txt tmp_static/Subset3/expression0.tsv.gz
# cp tmp_static/Subset4/names_rna.txt tmp_static/Subset4/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset4/names_rna.txt tmp_static/Subset4/expression0.tsv.gz
# cp tmp_static/Subset5/names_rna.txt tmp_static/Subset5/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset5/names_rna.txt tmp_static/Subset5/expression0.tsv.gz
# cp tmp_static/Subset6/names_rna.txt tmp_static/Subset6/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset6/names_rna.txt tmp_static/Subset6/expression0.tsv.gz
# cp tmp_static/Subset7/names_rna.txt tmp_static/Subset7/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset7/names_rna.txt tmp_static/Subset7/expression0.tsv.gz
# cp tmp_static/Subset8/names_rna.txt tmp_static/Subset8/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset8/names_rna.txt tmp_static/Subset8/expression0.tsv.gz
# cp tmp_static/Subset9/names_rna.txt tmp_static/Subset9/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset9/names_rna.txt tmp_static/Subset9/expression0.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset17/expression0.tsv.gz tmp_static/Subset17/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset16/expression0.tsv.gz tmp_static/Subset16/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset15/expression0.tsv.gz tmp_static/Subset15/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset17/expression.tsv.gz tmp_static/Subset17/names_atac0.txt tmp_static/Subset17/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset13/expression0.tsv.gz tmp_static/Subset13/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset10/expression0.tsv.gz tmp_static/Subset10/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset14/expression0.tsv.gz tmp_static/Subset14/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset17/names_atac.txt data/bams tmp_static/Subset17/reads.bam tmp_static/Subset17/reads.bai tmp_static/Subset17/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset9/expression0.tsv.gz tmp_static/Subset9/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset12/expression0.tsv.gz tmp_static/Subset12/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset11/expression0.tsv.gz tmp_static/Subset11/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset6/expression0.tsv.gz tmp_static/Subset6/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset16/expression.tsv.gz tmp_static/Subset16/names_atac0.txt tmp_static/Subset16/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset4/expression0.tsv.gz tmp_static/Subset4/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset8/expression0.tsv.gz tmp_static/Subset8/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset7/expression0.tsv.gz tmp_static/Subset7/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset15/expression.tsv.gz tmp_static/Subset15/names_atac0.txt tmp_static/Subset15/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset16/names_atac.txt data/bams tmp_static/Subset16/reads.bam tmp_static/Subset16/reads.bai tmp_static/Subset16/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset3/expression0.tsv.gz tmp_static/Subset3/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset13/expression.tsv.gz tmp_static/Subset13/names_atac0.txt tmp_static/Subset13/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset5/expression0.tsv.gz tmp_static/Subset5/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset15/names_atac.txt data/bams tmp_static/Subset15/reads.bam tmp_static/Subset15/reads.bai tmp_static/Subset15/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset10/expression.tsv.gz tmp_static/Subset10/names_atac0.txt tmp_static/Subset10/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset13/names_atac.txt data/bams tmp_static/Subset13/reads.bam tmp_static/Subset13/reads.bai tmp_static/Subset13/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset14/expression.tsv.gz tmp_static/Subset14/names_atac0.txt tmp_static/Subset14/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset2/expression0.tsv.gz tmp_static/Subset2/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset10/names_atac.txt data/bams tmp_static/Subset10/reads.bam tmp_static/Subset10/reads.bai tmp_static/Subset10/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset9/expression.tsv.gz tmp_static/Subset9/names_atac0.txt tmp_static/Subset9/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset7/expression.tsv.gz tmp_static/Subset7/names_atac0.txt tmp_static/Subset7/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset12/expression.tsv.gz tmp_static/Subset12/names_atac0.txt tmp_static/Subset12/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset11/expression.tsv.gz tmp_static/Subset11/names_atac0.txt tmp_static/Subset11/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset8/expression.tsv.gz tmp_static/Subset8/names_atac0.txt tmp_static/Subset8/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset6/expression.tsv.gz tmp_static/Subset6/names_atac0.txt tmp_static/Subset6/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset14/names_atac.txt data/bams tmp_static/Subset14/reads.bam tmp_static/Subset14/reads.bai tmp_static/Subset14/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset4/expression.tsv.gz tmp_static/Subset4/names_atac0.txt tmp_static/Subset4/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset9/names_atac.txt data/bams tmp_static/Subset9/reads.bam tmp_static/Subset9/reads.bai tmp_static/Subset9/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset7/names_atac.txt data/bams tmp_static/Subset7/reads.bam tmp_static/Subset7/reads.bai tmp_static/Subset7/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset12/names_atac.txt data/bams tmp_static/Subset12/reads.bam tmp_static/Subset12/reads.bai tmp_static/Subset12/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset11/names_atac.txt data/bams tmp_static/Subset11/reads.bam tmp_static/Subset11/reads.bai tmp_static/Subset11/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset3/expression.tsv.gz tmp_static/Subset3/names_atac0.txt tmp_static/Subset3/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset6/names_atac.txt data/bams tmp_static/Subset6/reads.bam tmp_static/Subset6/reads.bai tmp_static/Subset6/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset8/names_atac.txt data/bams tmp_static/Subset8/reads.bam tmp_static/Subset8/reads.bai tmp_static/Subset8/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset4/names_atac.txt data/bams tmp_static/Subset4/reads.bam tmp_static/Subset4/reads.bai tmp_static/Subset4/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset5/expression.tsv.gz tmp_static/Subset5/names_atac0.txt tmp_static/Subset5/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset1/expression0.tsv.gz tmp_static/Subset1/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset3/names_atac.txt data/bams tmp_static/Subset3/reads.bam tmp_static/Subset3/reads.bai tmp_static/Subset3/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset2/expression.tsv.gz tmp_static/Subset2/names_atac0.txt tmp_static/Subset2/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset5/names_atac.txt data/bams tmp_static/Subset5/reads.bam tmp_static/Subset5/reads.bai tmp_static/Subset5/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset1/expression.tsv.gz tmp_static/Subset1/names_atac0.txt tmp_static/Subset1/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset2/names_atac.txt data/bams tmp_static/Subset2/reads.bam tmp_static/Subset2/reads.bai tmp_static/Subset2/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset1/names_atac.txt data/bams tmp_static/Subset1/reads.bam tmp_static/Subset1/reads.bai tmp_static/Subset1/peaks.bed hs
# [bam_sort_core] merging from 1 files and 4 in-memory blocks...
# INFO  @ Fri, 02 Aug 2024 12:22:06:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset17/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset17/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Fri, 02 Aug 2024 12:22:06: #1 read tag files...
# INFO  @ Fri, 02 Aug 2024 12:22:06: #1 read treatment tags...
# DEBUG @ Fri, 02 Aug 2024 12:22:06: Testing format BAM
# INFO  @ Fri, 02 Aug 2024 12:22:06: Detected format is: BAM
# INFO  @ Fri, 02 Aug 2024 12:22:06: * Input file is gzipped.
# INFO  @ Fri, 02 Aug 2024 12:22:09:  1000000
# INFO  @ Fri, 02 Aug 2024 12:22:12:  2000000
# INFO  @ Fri, 02 Aug 2024 12:22:15:  3000000
# INFO  @ Fri, 02 Aug 2024 12:22:18:  4000000
# INFO  @ Fri, 02 Aug 2024 12:22:21: 4924143 reads have been read.
# INFO  @ Fri, 02 Aug 2024 12:22:21: #1 tag size is determined as 50 bps
# INFO  @ Fri, 02 Aug 2024 12:22:21: #1 tag size = 50.0
# INFO  @ Fri, 02 Aug 2024 12:22:21: #1  total tags in treatment: 4924143
# INFO  @ Fri, 02 Aug 2024 12:22:21: #1 finished!
# INFO  @ Fri, 02 Aug 2024 12:22:21: #2 Build Peak Model...
# INFO  @ Fri, 02 Aug 2024 12:22:21: #2 Skipped...
# INFO  @ Fri, 02 Aug 2024 12:22:21: #2 Use 150 as fragment length
# INFO  @ Fri, 02 Aug 2024 12:22:21: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Fri, 02 Aug 2024 12:22:21: #3 Call peaks...
# INFO  @ Fri, 02 Aug 2024 12:22:21: #3 Going to call summits inside each peak ...
# INFO  @ Fri, 02 Aug 2024 12:22:21: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Fri, 02 Aug 2024 12:22:21: Start to calculate pvalue stat...
# DEBUG @ Fri, 02 Aug 2024 12:22:26: access pq hash for 10979677 times
# INFO  @ Fri, 02 Aug 2024 12:22:26: #3 Call peaks for each chromosome...
# INFO  @ Fri, 02 Aug 2024 12:23:06: #4 Write output xls file... 04_peaks.xls
# INFO  @ Fri, 02 Aug 2024 12:23:06: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Fri, 02 Aug 2024 12:23:07: #4 Write summits bed file... 04_summits.bed
# INFO  @ Fri, 02 Aug 2024 12:23:07: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset17/reads.bam tmp_static/Subset17/reads.bai tmp_static/Subset17/peaks.bed tmp_static/Subset17/footprints.bed
# [bam_sort_core] merging from 2 files and 4 in-memory blocks...
# INFO  @ Fri, 02 Aug 2024 12:25:22:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset16/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset16/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Fri, 02 Aug 2024 12:25:22: #1 read tag files...
# INFO  @ Fri, 02 Aug 2024 12:25:22: #1 read treatment tags...
# DEBUG @ Fri, 02 Aug 2024 12:25:22: Testing format BAM
# INFO  @ Fri, 02 Aug 2024 12:25:22: Detected format is: BAM
# INFO  @ Fri, 02 Aug 2024 12:25:22: * Input file is gzipped.
# INFO  @ Fri, 02 Aug 2024 12:25:25:  1000000
# INFO  @ Fri, 02 Aug 2024 12:25:28:  2000000
# INFO  @ Fri, 02 Aug 2024 12:25:31:  3000000
# INFO  @ Fri, 02 Aug 2024 12:25:34:  4000000
# INFO  @ Fri, 02 Aug 2024 12:25:37:  5000000
# INFO  @ Fri, 02 Aug 2024 12:25:40:  6000000
# INFO  @ Fri, 02 Aug 2024 12:25:43:  7000000
# INFO  @ Fri, 02 Aug 2024 12:25:46:  8000000
# INFO  @ Fri, 02 Aug 2024 12:25:49: 8749075 reads have been read.
# INFO  @ Fri, 02 Aug 2024 12:25:49: #1 tag size is determined as 49 bps
# INFO  @ Fri, 02 Aug 2024 12:25:49: #1 tag size = 49.0
# INFO  @ Fri, 02 Aug 2024 12:25:49: #1  total tags in treatment: 8749075
# INFO  @ Fri, 02 Aug 2024 12:25:49: #1 finished!
# INFO  @ Fri, 02 Aug 2024 12:25:49: #2 Build Peak Model...
# INFO  @ Fri, 02 Aug 2024 12:25:49: #2 Skipped...
# INFO  @ Fri, 02 Aug 2024 12:25:49: #2 Use 150 as fragment length
# INFO  @ Fri, 02 Aug 2024 12:25:49: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Fri, 02 Aug 2024 12:25:49: #3 Call peaks...
# INFO  @ Fri, 02 Aug 2024 12:25:49: #3 Going to call summits inside each peak ...
# INFO  @ Fri, 02 Aug 2024 12:25:49: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Fri, 02 Aug 2024 12:25:49: Start to calculate pvalue stat...
# DEBUG @ Fri, 02 Aug 2024 12:25:59: access pq hash for 16389906 times
# INFO  @ Fri, 02 Aug 2024 12:25:59: #3 Call peaks for each chromosome...
# INFO  @ Fri, 02 Aug 2024 12:26:25: #4 Write output xls file... 04_peaks.xls
# INFO  @ Fri, 02 Aug 2024 12:26:25: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Fri, 02 Aug 2024 12:26:25: #4 Write summits bed file... 04_summits.bed
# INFO  @ Fri, 02 Aug 2024 12:26:25: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset16/reads.bam tmp_static/Subset16/reads.bai tmp_static/Subset16/peaks.bed tmp_static/Subset16/footprints.bed
# [bam_sort_core] merging from 2 files and 4 in-memory blocks...
# INFO  @ Fri, 02 Aug 2024 12:27:23:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset13/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset13/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Fri, 02 Aug 2024 12:27:23: #1 read tag files...
# INFO  @ Fri, 02 Aug 2024 12:27:23: #1 read treatment tags...
# DEBUG @ Fri, 02 Aug 2024 12:27:23: Testing format BAM
# INFO  @ Fri, 02 Aug 2024 12:27:23: Detected format is: BAM
# INFO  @ Fri, 02 Aug 2024 12:27:23: * Input file is gzipped.
# INFO  @ Fri, 02 Aug 2024 12:27:26:  1000000
# INFO  @ Fri, 02 Aug 2024 12:27:29:  2000000
# INFO  @ Fri, 02 Aug 2024 12:27:32:  3000000
# INFO  @ Fri, 02 Aug 2024 12:27:35:  4000000
# INFO  @ Fri, 02 Aug 2024 12:27:38:  5000000
# INFO  @ Fri, 02 Aug 2024 12:27:41:  6000000
# INFO  @ Fri, 02 Aug 2024 12:27:44:  7000000
# INFO  @ Fri, 02 Aug 2024 12:27:47:  8000000
# INFO  @ Fri, 02 Aug 2024 12:27:50:  9000000
# INFO  @ Fri, 02 Aug 2024 12:27:53:  10000000
# INFO  @ Fri, 02 Aug 2024 12:27:56: 10748254 reads have been read.
# INFO  @ Fri, 02 Aug 2024 12:27:56: #1 tag size is determined as 49 bps
# INFO  @ Fri, 02 Aug 2024 12:27:56: #1 tag size = 49.0
# INFO  @ Fri, 02 Aug 2024 12:27:56: #1  total tags in treatment: 10748254
# INFO  @ Fri, 02 Aug 2024 12:27:56: #1 finished!
# INFO  @ Fri, 02 Aug 2024 12:27:56: #2 Build Peak Model...
# INFO  @ Fri, 02 Aug 2024 12:27:56: #2 Skipped...
# INFO  @ Fri, 02 Aug 2024 12:27:56: #2 Use 150 as fragment length
# INFO  @ Fri, 02 Aug 2024 12:27:56: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Fri, 02 Aug 2024 12:27:56: #3 Call peaks...
# INFO  @ Fri, 02 Aug 2024 12:27:56: #3 Going to call summits inside each peak ...
# INFO  @ Fri, 02 Aug 2024 12:27:56: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Fri, 02 Aug 2024 12:27:56: Start to calculate pvalue stat...
# DEBUG @ Fri, 02 Aug 2024 12:28:10: access pq hash for 19005632 times
# INFO  @ Fri, 02 Aug 2024 12:28:10: #3 Call peaks for each chromosome...
# INFO  @ Fri, 02 Aug 2024 12:28:37: #4 Write output xls file... 04_peaks.xls
# INFO  @ Fri, 02 Aug 2024 12:28:38: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Fri, 02 Aug 2024 12:28:38: #4 Write summits bed file... 04_summits.bed
# INFO  @ Fri, 02 Aug 2024 12:28:38: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset13/reads.bam tmp_static/Subset13/reads.bai tmp_static/Subset13/peaks.bed tmp_static/Subset13/footprints.bed
# [bam_sort_core] merging from 3 files and 4 in-memory blocks...
# INFO  @ Fri, 02 Aug 2024 12:28:06:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset15/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset15/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Fri, 02 Aug 2024 12:28:06: #1 read tag files...
# INFO  @ Fri, 02 Aug 2024 12:28:06: #1 read treatment tags...
# DEBUG @ Fri, 02 Aug 2024 12:28:06: Testing format BAM
# INFO  @ Fri, 02 Aug 2024 12:28:06: Detected format is: BAM
# INFO  @ Fri, 02 Aug 2024 12:28:06: * Input file is gzipped.
# INFO  @ Fri, 02 Aug 2024 12:28:09:  1000000
# INFO  @ Fri, 02 Aug 2024 12:28:12:  2000000
# INFO  @ Fri, 02 Aug 2024 12:28:15:  3000000
# INFO  @ Fri, 02 Aug 2024 12:28:19:  4000000
# INFO  @ Fri, 02 Aug 2024 12:28:22:  5000000
# INFO  @ Fri, 02 Aug 2024 12:28:25:  6000000
# INFO  @ Fri, 02 Aug 2024 12:28:28:  7000000
# INFO  @ Fri, 02 Aug 2024 12:28:31:  8000000
# INFO  @ Fri, 02 Aug 2024 12:28:34:  9000000
# INFO  @ Fri, 02 Aug 2024 12:28:38:  10000000
# INFO  @ Fri, 02 Aug 2024 12:28:41:  11000000
# INFO  @ Fri, 02 Aug 2024 12:28:44: 11955586 reads have been read.
# INFO  @ Fri, 02 Aug 2024 12:28:44: #1 tag size is determined as 49 bps
# INFO  @ Fri, 02 Aug 2024 12:28:44: #1 tag size = 49.0
# INFO  @ Fri, 02 Aug 2024 12:28:44: #1  total tags in treatment: 11955586
# INFO  @ Fri, 02 Aug 2024 12:28:44: #1 finished!
# INFO  @ Fri, 02 Aug 2024 12:28:44: #2 Build Peak Model...
# INFO  @ Fri, 02 Aug 2024 12:28:44: #2 Skipped...
# INFO  @ Fri, 02 Aug 2024 12:28:44: #2 Use 150 as fragment length
# INFO  @ Fri, 02 Aug 2024 12:28:44: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Fri, 02 Aug 2024 12:28:44: #3 Call peaks...
# INFO  @ Fri, 02 Aug 2024 12:28:44: #3 Going to call summits inside each peak ...
# INFO  @ Fri, 02 Aug 2024 12:28:44: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Fri, 02 Aug 2024 12:28:44: Start to calculate pvalue stat...
# DEBUG @ Fri, 02 Aug 2024 12:28:59: access pq hash for 21232508 times
# INFO  @ Fri, 02 Aug 2024 12:28:59: #3 Call peaks for each chromosome...
# INFO  @ Fri, 02 Aug 2024 12:29:25: #4 Write output xls file... 04_peaks.xls
# INFO  @ Fri, 02 Aug 2024 12:29:25: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Fri, 02 Aug 2024 12:29:25: #4 Write summits bed file... 04_summits.bed
# INFO  @ Fri, 02 Aug 2024 12:29:25: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset15/reads.bam tmp_static/Subset15/reads.bai tmp_static/Subset15/peaks.bed tmp_static/Subset15/footprints.bed
# [bam_sort_core] merging from 3 files and 4 in-memory blocks...
# INFO  @ Fri, 02 Aug 2024 12:30:01:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset10/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset10/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Fri, 02 Aug 2024 12:30:01: #1 read tag files...
# INFO  @ Fri, 02 Aug 2024 12:30:01: #1 read treatment tags...
# DEBUG @ Fri, 02 Aug 2024 12:30:01: Testing format BAM
# INFO  @ Fri, 02 Aug 2024 12:30:01: Detected format is: BAM
# INFO  @ Fri, 02 Aug 2024 12:30:01: * Input file is gzipped.
# INFO  @ Fri, 02 Aug 2024 12:30:04:  1000000
# INFO  @ Fri, 02 Aug 2024 12:30:07:  2000000
# INFO  @ Fri, 02 Aug 2024 12:30:10:  3000000
# INFO  @ Fri, 02 Aug 2024 12:30:13:  4000000
# INFO  @ Fri, 02 Aug 2024 12:30:16:  5000000
# INFO  @ Fri, 02 Aug 2024 12:30:19:  6000000
# INFO  @ Fri, 02 Aug 2024 12:30:22:  7000000
# INFO  @ Fri, 02 Aug 2024 12:30:25:  8000000
# INFO  @ Fri, 02 Aug 2024 12:30:28:  9000000
# INFO  @ Fri, 02 Aug 2024 12:30:31:  10000000
# INFO  @ Fri, 02 Aug 2024 12:30:34:  11000000
# INFO  @ Fri, 02 Aug 2024 12:30:37:  12000000
# INFO  @ Fri, 02 Aug 2024 12:30:39: 12731137 reads have been read.
# INFO  @ Fri, 02 Aug 2024 12:30:40: #1 tag size is determined as 49 bps
# INFO  @ Fri, 02 Aug 2024 12:30:40: #1 tag size = 49.0
# INFO  @ Fri, 02 Aug 2024 12:30:40: #1  total tags in treatment: 12731137
# INFO  @ Fri, 02 Aug 2024 12:30:40: #1 finished!
# INFO  @ Fri, 02 Aug 2024 12:30:40: #2 Build Peak Model...
# INFO  @ Fri, 02 Aug 2024 12:30:40: #2 Skipped...
# INFO  @ Fri, 02 Aug 2024 12:30:40: #2 Use 150 as fragment length
# INFO  @ Fri, 02 Aug 2024 12:30:40: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Fri, 02 Aug 2024 12:30:40: #3 Call peaks...
# INFO  @ Fri, 02 Aug 2024 12:30:40: #3 Going to call summits inside each peak ...
# INFO  @ Fri, 02 Aug 2024 12:30:40: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Fri, 02 Aug 2024 12:30:40: Start to calculate pvalue stat...
# DEBUG @ Fri, 02 Aug 2024 12:30:55: access pq hash for 21592680 times
# INFO  @ Fri, 02 Aug 2024 12:30:55: #3 Call peaks for each chromosome...
# INFO  @ Fri, 02 Aug 2024 12:31:20: #4 Write output xls file... 04_peaks.xls
# INFO  @ Fri, 02 Aug 2024 12:31:20: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Fri, 02 Aug 2024 12:31:21: #4 Write summits bed file... 04_summits.bed
# INFO  @ Fri, 02 Aug 2024 12:31:21: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset10/reads.bam tmp_static/Subset10/reads.bai tmp_static/Subset10/peaks.bed tmp_static/Subset10/footprints.bed
# [bam_sort_core] merging from 3 files and 4 in-memory blocks...
# INFO  @ Fri, 02 Aug 2024 12:31:44:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset11/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset11/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Fri, 02 Aug 2024 12:31:44: #1 read tag files...
# INFO  @ Fri, 02 Aug 2024 12:31:44: #1 read treatment tags...
# DEBUG @ Fri, 02 Aug 2024 12:31:44: Testing format BAM
# INFO  @ Fri, 02 Aug 2024 12:31:44: Detected format is: BAM
# INFO  @ Fri, 02 Aug 2024 12:31:44: * Input file is gzipped.
# INFO  @ Fri, 02 Aug 2024 12:31:47:  1000000
# INFO  @ Fri, 02 Aug 2024 12:31:50:  2000000
# INFO  @ Fri, 02 Aug 2024 12:31:53:  3000000
# INFO  @ Fri, 02 Aug 2024 12:31:56:  4000000
# INFO  @ Fri, 02 Aug 2024 12:31:59:  5000000
# INFO  @ Fri, 02 Aug 2024 12:32:02:  6000000
# INFO  @ Fri, 02 Aug 2024 12:32:05:  7000000
# INFO  @ Fri, 02 Aug 2024 12:32:08:  8000000
# INFO  @ Fri, 02 Aug 2024 12:32:11:  9000000
# INFO  @ Fri, 02 Aug 2024 12:32:14:  10000000
# INFO  @ Fri, 02 Aug 2024 12:32:17:  11000000
# INFO  @ Fri, 02 Aug 2024 12:32:20:  12000000
# INFO  @ Fri, 02 Aug 2024 12:32:23:  13000000
# INFO  @ Fri, 02 Aug 2024 12:32:26: 13961329 reads have been read.
# INFO  @ Fri, 02 Aug 2024 12:32:26: #1 tag size is determined as 49 bps
# INFO  @ Fri, 02 Aug 2024 12:32:26: #1 tag size = 49.0
# INFO  @ Fri, 02 Aug 2024 12:32:26: #1  total tags in treatment: 13961329
# INFO  @ Fri, 02 Aug 2024 12:32:26: #1 finished!
# INFO  @ Fri, 02 Aug 2024 12:32:26: #2 Build Peak Model...
# INFO  @ Fri, 02 Aug 2024 12:32:26: #2 Skipped...
# INFO  @ Fri, 02 Aug 2024 12:32:26: #2 Use 150 as fragment length
# INFO  @ Fri, 02 Aug 2024 12:32:26: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Fri, 02 Aug 2024 12:32:26: #3 Call peaks...
# INFO  @ Fri, 02 Aug 2024 12:32:26: #3 Going to call summits inside each peak ...
# INFO  @ Fri, 02 Aug 2024 12:32:26: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Fri, 02 Aug 2024 12:32:26: Start to calculate pvalue stat...
# DEBUG @ Fri, 02 Aug 2024 12:32:44: access pq hash for 25300891 times
# INFO  @ Fri, 02 Aug 2024 12:32:44: #3 Call peaks for each chromosome...
# INFO  @ Fri, 02 Aug 2024 12:33:17: #4 Write output xls file... 04_peaks.xls
# INFO  @ Fri, 02 Aug 2024 12:33:17: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Fri, 02 Aug 2024 12:33:18: #4 Write summits bed file... 04_summits.bed
# INFO  @ Fri, 02 Aug 2024 12:33:18: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset11/reads.bam tmp_static/Subset11/reads.bai tmp_static/Subset11/peaks.bed tmp_static/Subset11/footprints.bed
# [bam_sort_core] merging from 4 files and 4 in-memory blocks...
# INFO  @ Fri, 02 Aug 2024 12:34:04:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset14/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset14/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Fri, 02 Aug 2024 12:34:04: #1 read tag files...
# INFO  @ Fri, 02 Aug 2024 12:34:04: #1 read treatment tags...
# DEBUG @ Fri, 02 Aug 2024 12:34:05: Testing format BAM
# INFO  @ Fri, 02 Aug 2024 12:34:05: Detected format is: BAM
# INFO  @ Fri, 02 Aug 2024 12:34:05: * Input file is gzipped.
# INFO  @ Fri, 02 Aug 2024 12:34:08:  1000000
# INFO  @ Fri, 02 Aug 2024 12:34:11:  2000000
# INFO  @ Fri, 02 Aug 2024 12:34:14:  3000000
# INFO  @ Fri, 02 Aug 2024 12:34:17:  4000000
# INFO  @ Fri, 02 Aug 2024 12:34:20:  5000000
# INFO  @ Fri, 02 Aug 2024 12:34:23:  6000000
# INFO  @ Fri, 02 Aug 2024 12:34:26:  7000000
# INFO  @ Fri, 02 Aug 2024 12:34:29:  8000000
# INFO  @ Fri, 02 Aug 2024 12:34:32:  9000000
# INFO  @ Fri, 02 Aug 2024 12:34:35:  10000000
# INFO  @ Fri, 02 Aug 2024 12:34:38:  11000000
# INFO  @ Fri, 02 Aug 2024 12:34:41:  12000000
# INFO  @ Fri, 02 Aug 2024 12:34:44:  13000000
# INFO  @ Fri, 02 Aug 2024 12:34:47:  14000000
# INFO  @ Fri, 02 Aug 2024 12:34:50:  15000000
# INFO  @ Fri, 02 Aug 2024 12:34:53:  16000000
# INFO  @ Fri, 02 Aug 2024 12:34:56:  17000000
# INFO  @ Fri, 02 Aug 2024 12:34:59:  18000000
# INFO  @ Fri, 02 Aug 2024 12:35:00: 18409803 reads have been read.
# INFO  @ Fri, 02 Aug 2024 12:35:00: #1 tag size is determined as 49 bps
# INFO  @ Fri, 02 Aug 2024 12:35:00: #1 tag size = 49.0
# INFO  @ Fri, 02 Aug 2024 12:35:00: #1  total tags in treatment: 18409803
# INFO  @ Fri, 02 Aug 2024 12:35:00: #1 finished!
# INFO  @ Fri, 02 Aug 2024 12:35:00: #2 Build Peak Model...
# INFO  @ Fri, 02 Aug 2024 12:35:00: #2 Skipped...
# INFO  @ Fri, 02 Aug 2024 12:35:00: #2 Use 150 as fragment length
# INFO  @ Fri, 02 Aug 2024 12:35:00: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Fri, 02 Aug 2024 12:35:00: #3 Call peaks...
# INFO  @ Fri, 02 Aug 2024 12:35:00: #3 Going to call summits inside each peak ...
# INFO  @ Fri, 02 Aug 2024 12:35:00: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Fri, 02 Aug 2024 12:35:00: Start to calculate pvalue stat...
# DEBUG @ Fri, 02 Aug 2024 12:35:24: access pq hash for 33583381 times
# INFO  @ Fri, 02 Aug 2024 12:35:24: #3 Call peaks for each chromosome...
# INFO  @ Fri, 02 Aug 2024 12:36:07: #4 Write output xls file... 04_peaks.xls
# INFO  @ Fri, 02 Aug 2024 12:36:08: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Fri, 02 Aug 2024 12:36:08: #4 Write summits bed file... 04_summits.bed
# INFO  @ Fri, 02 Aug 2024 12:36:08: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset14/reads.bam tmp_static/Subset14/reads.bai tmp_static/Subset14/peaks.bed tmp_static/Subset14/footprints.bed
# [bam_sort_core] merging from 4 files and 4 in-memory blocks...
# INFO  @ Fri, 02 Aug 2024 12:36:04:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset7/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys/tmp_static/Subset7/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Fri, 02 Aug 2024 12:36:04: #1 read tag files...
# INFO  @ Fri, 02 Aug 2024 12:36:04: #1 read treatment tags...
# DEBUG @ Fri, 02 Aug 2024 12:36:04: Testing format BAM
# INFO  @ Fri, 02 Aug 2024 12:36:05: Detected format is: BAM
# INFO  @ Fri, 02 Aug 2024 12:36:05: * Input file is gzipped.
# INFO  @ Fri, 02 Aug 2024 12:36:08:  1000000
# INFO  @ Fri, 02 Aug 2024 12:36:11:  2000000
# INFO  @ Fri, 02 Aug 2024 12:36:14:  3000000
# INFO  @ Fri, 02 Aug 2024 12:36:17:  4000000
# INFO  @ Fri, 02 Aug 2024 12:36:20:  5000000
# INFO  @ Fri, 02 Aug 2024 12:36:23:  6000000
# INFO  @ Fri, 02 Aug 2024 12:36:26:  7000000
# INFO  @ Fri, 02 Aug 2024 12:36:29:  8000000
# INFO  @ Fri, 02 Aug 2024 12:36:32:  9000000
# INFO  @ Fri, 02 Aug 2024 12:36:35:  10000000
# INFO  @ Fri, 02 Aug 2024 12:36:39:  11000000
# INFO  @ Fri, 02 Aug 2024 12:36:42:  12000000
# ...
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset15/net_meanvar.tsv.gz tmp_static/Subset15/net_weight.tsv.gz tmp_static/Subset15/net_covfactor.tsv.gz tmp_static/Subset15/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset15/net_iweight.tsv.gz tmp_static/Subset15/net_meanvar.tsv.gz tmp_static/Subset15/net_covfactor.tsv.gz tmp_static/Subset15/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset13/net_weight.tsv.gz tmp_static/Subset13/net_meanvar.tsv.gz tmp_static/Subset13/net_covfactor.tsv.gz tmp_static/Subset13/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset13/net_meanvar.tsv.gz tmp_static/Subset13/net_weight.tsv.gz tmp_static/Subset13/net_covfactor.tsv.gz tmp_static/Subset13/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset13/net_iweight.tsv.gz tmp_static/Subset13/net_meanvar.tsv.gz tmp_static/Subset13/net_covfactor.tsv.gz tmp_static/Subset13/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset7/net_iweight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset8/net_weight.tsv.gz tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_weight.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset8/net_iweight.tsv.gz tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset9/net_iweight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset10/net_weight.tsv.gz tmp_static/Subset10/net_meanvar.tsv.gz tmp_static/Subset10/net_covfactor.tsv.gz tmp_static/Subset10/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset10/net_meanvar.tsv.gz tmp_static/Subset10/net_weight.tsv.gz tmp_static/Subset10/net_covfactor.tsv.gz tmp_static/Subset10/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset10/net_iweight.tsv.gz tmp_static/Subset10/net_meanvar.tsv.gz tmp_static/Subset10/net_covfactor.tsv.gz tmp_static/Subset10/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset12/net_weight.tsv.gz tmp_static/Subset12/net_meanvar.tsv.gz tmp_static/Subset12/net_covfactor.tsv.gz tmp_static/Subset12/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset12/net_meanvar.tsv.gz tmp_static/Subset12/net_weight.tsv.gz tmp_static/Subset12/net_covfactor.tsv.gz tmp_static/Subset12/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset12/net_iweight.tsv.gz tmp_static/Subset12/net_meanvar.tsv.gz tmp_static/Subset12/net_covfactor.tsv.gz tmp_static/Subset12/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset3/net_iweight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset6/net_iweight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset11/net_weight.tsv.gz tmp_static/Subset11/net_meanvar.tsv.gz tmp_static/Subset11/net_covfactor.tsv.gz tmp_static/Subset11/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset11/net_meanvar.tsv.gz tmp_static/Subset11/net_weight.tsv.gz tmp_static/Subset11/net_covfactor.tsv.gz tmp_static/Subset11/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset11/net_iweight.tsv.gz tmp_static/Subset11/net_meanvar.tsv.gz tmp_static/Subset11/net_covfactor.tsv.gz tmp_static/Subset11/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset4/net_iweight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset14/net_weight.tsv.gz tmp_static/Subset14/net_meanvar.tsv.gz tmp_static/Subset14/net_covfactor.tsv.gz tmp_static/Subset14/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset14/net_meanvar.tsv.gz tmp_static/Subset14/net_weight.tsv.gz tmp_static/Subset14/net_covfactor.tsv.gz tmp_static/Subset14/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset14/net_iweight.tsv.gz tmp_static/Subset14/net_meanvar.tsv.gz tmp_static/Subset14/net_covfactor.tsv.gz tmp_static/Subset14/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset5/net_iweight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset2/net_weight.tsv.gz tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_weight.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset2/net_iweight.tsv.gz tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset1/net_weight.tsv.gz tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_weight.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset1/net_iweight.tsv.gz tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_inweight.tsv.gz
# make: Nothing to be done for 'cpu'.
# make: Nothing to be done for 'gpu'.
# make: Nothing to be done for 'cpu'.
# mkdir -p output/
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network tofile  data tmp_static data/subsets.txt output/static.h5
# 	Command being timed: "dictys_helper network_inference.sh -j 32 -J 1 static"
# 	User time (seconds): 1888306.40
# 	System time (seconds): 60382.78
# 	Percent of CPU this job got: 2316%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 23:22:18
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 6561684
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 2551
# 	Minor (reclaiming a frame) page faults: 3570822734
# 	Voluntary context switches: 370192451
# 	Involuntary context switches: 223650176
# 	Swaps: 0
# 	File system inputs: 268634144
# 	File system outputs: 322552624
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0
