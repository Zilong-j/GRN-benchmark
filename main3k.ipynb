# %%
# %load_ext memory_profiler

# %% [markdown]
# # Short tutorial: context-specific GRN inference from 10x multiome dataset
# This is a [Dictys](https://github.com/pinellolab/dictys) tutorial to reconstruct and analyze context-specific GRNs from a [10x multiome dataset on PBMC](https://www.10xgenomics.com/resources/datasets/pbmc-from-a-healthy-donor-granulocytes-removed-through-cell-sorting-10-k-1-standard-2-0-0). For a full version with details of individual steps, see tutorial [full-multiome](https://github.com/pinellolab/dictys/tree/master/doc/tutorials/full-multiome).
#
# Before running, you need to **change the runtime configurations** for your machine at [2. Network inference configuration](#2.-Network-inference-configuration) and [3. Network inference](#3.-Network-inference).
#
# If you face any issues or need any assistance, see [FAQ](https://github.com/pinellolab/dictys#faq) and [Issues](https://github.com/pinellolab/dictys#issues).
#
# By using this notebook, you imply that you have already accepted the terms of use and privacy policy on the [10x dataset webpage](https://www.10xgenomics.com/resources/datasets/pbmc-from-a-healthy-donor-granulocytes-removed-through-cell-sorting-10-k-1-standard-2-0-0). The dataset summary webpage is also available [here](https://cf.10xgenomics.com/samples/cell-arc/2.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_web_summary.html).

# %% [markdown]
# ## 1. Preparation of individual input files in `data` folder
# After data processing with CellRanger, you need the following files:
# * RNA read count matrix ("Filtered feature barcode matrix MEX (DIR)")
# * ATAC reads ("ATAC Position-sorted alignments (BAM)")
# * Optionally or from other softwares: cell clustering (inside "Secondary analysis outputs (DIR)")

# %%
import os

# 更新 PATH 环境变量，添加 Conda 环境的 bin 目录
os.environ['PATH'] = os.path.expanduser('~/.conda/envs/dictys/bin') + ':' + os.environ['PATH']

# 确保路径已更新
print(os.getenv('PATH'))

# 尝试运行命令
#os.system('dictys_helper expression_mtx.py -h')
# Out:
# /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/.conda/envs/dictys/bin:/opt/gridware/apps/gcc/R/4.3.2/bin:/opt/gridware/compilers/gcc/11.2.0/bin:/opt/gridware2/apps/binapps/anaconda3/2019.07/bin:/opt/gridware2/apps/binapps/anaconda3/2019.07/condabin:/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/.local/bin:/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/bin:/usr/share/Modules/bin:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin

# %%
# Removes CPU usage limit by some jupyter versions
import os
os.environ['KMP_AFFINITY'] = ''
#Create input data folder
current_path = os.getcwd()
print(current_path)
# Out:
# /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys

# %%
current_path = "/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k"
os.chdir(current_path )

# %%
os.getcwd()
# Out:
# '/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k'

# %%
# %%bash
# cd ./data

# %% [markdown]
# ### expression.tsv.gz
# Read count matrix of RNA-profiled cells in compressed tsv format. Downloaded and converted from "Filtered feature barcode matrix MEX (DIR)".

# %%
# %%bash
# cd ./data
# # Download expression data in mtx.gz format
# wget -q -o /dev/null https://cf.10xgenomics.com/samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_3k/pbmc_granulocyte_sorted_3k_filtered_feature_bc_matrix.tar.gz
# tar xf pbmc_granulocyte_sorted_3k_filtered_feature_bc_matrix.tar.gz
# rm pbmc_granulocyte_sorted_3k_filtered_feature_bc_matrix.tar.gz
# # Convert from mtx.gz to tsv.gz format using helper script `expression_mtx.py`.
# dictys_helper expression_mtx.py filtered_feature_bc_matrix expression.tsv.gz
# rm -Rf filtered_feature_bc_matrix
# Out:
# WARNING:root:Skipped duplicate occurrence of gene names: TBCE,LINC01238,CYB561D2,MATR3,LINC01505,HSPA14,GOLGA8M,GGT1,ARMCX5-GPRASP2,TMSB15B

# %% [markdown]
# ### bams
# This folder contains one bam file for each cell with chromatin accessibility measurement. File name should be cell name. Downloaded and converted from "ATAC Position-sorted alignments (BAM)".
# * **This step can take hours or even over a day**
# * The default setting will need ~30GB of memory for this dataset. Specify a lower `--buffer_size 1000` or smaller for `dictys_helper split_bam.sh` if you have less memory.

# %%
# %%bash
# set -eo pipefail
# cd ./data
# # Download chromatin accessibility reads in bam format
# wget --debug --progress=bar:force:noscroll -O bams.bam https://cf.10xgenomics.com/samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_3k/pbmc_granulocyte_sorted_3k_atac_possorted_bam.bam
# Out:
# Setting --progress (progress) to bar:force:noscroll
# Setting --output-document (outputdocument) to bams.bam
# DEBUG output created by Wget 1.21.4 on linux-gnu.
#
# Reading HSTS entries from /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/.wget-hsts
# URI encoding = ‘UTF-8’
# --2024-08-01 15:03:26--  https://cf.10xgenomics.com/samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_3k/pbmc_granulocyte_sorted_3k_atac_possorted_bam.bam
# Resolving cf.10xgenomics.com (cf.10xgenomics.com)... 104.18.1.173, 104.18.0.173, 2606:4700::6812:ad, ...
# Caching cf.10xgenomics.com => 104.18.1.173 104.18.0.173 2606:4700::6812:ad 2606:4700::6812:1ad
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:443... connected.
# Created socket 4.
# Releasing 0x0000558dffbeaf70 (new refcount 1).
# Initiating SSL handshake.
# Handshake successful; connected socket 4 to SSL handle 0x0000558dffbf69d0
# certificate:
#   subject: CN=10xgenomics.com
#   issuer:  CN=WE1,O=Google Trust Services,C=US
# X509 certificate successfully verified and matches host cf.10xgenomics.com
#
# ---request begin---
# GET /samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_3k/pbmc_granulocyte_sorted_3k_atac_possorted_bam.bam HTTP/1.1
# Host: cf.10xgenomics.com
# User-Agent: Wget/1.21.4
# Accept: */*
# Accept-Encoding: identity
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 200 OK
# Date: Thu, 01 Aug 2024 14:03:27 GMT
# Content-Type: binary/octet-stream
# Content-Length: 8468267067
# Connection: keep-alive
# last-modified: Sun, 06 Sep 2020 06:51:03 GMT
# etag: "5a1d2e3a06057ff2fa4ee9c3c27d0e5b-1010"
# x-amz-storage-class: INTELLIGENT_TIERING
# x-amz-version-id: 4c7byHEQTUIqmfXZOpLjwRD9WI2NuY2I
# accept-ranges: bytes
# x-cache: Miss from cloudfront
# via: 1.1 31ef019c1ddee9b68951720b335aec36.cloudfront.net (CloudFront)
# x-amz-cf-pop: LHR5-P5
# x-amz-cf-id: uQ18niaNwUmD959phECVqBVhcvs-A33zdwzfuJJt90paaS5piXVuaA==
# CF-Cache-Status: DYNAMIC
# Server: cloudflare
# CF-RAY: 8ac65f24be91ccaa-MAN
#
# ---response end---
# 200 OK
# Registered socket 4 for persistent reuse.
# Length: 8468267067 (7.9G) [binary/octet-stream]
# Saving to: ‘bams.bam’
#
# bams.bam            100%[===================>]   7.89G  7.56MB/s    in 24m 40s
#
# 2024-08-01 15:28:07 (5.46 MB/s) - ‘bams.bam’ saved [8468267067/8468267067]

# %%
# %%bash
# set -eo pipefail
# cd ./data
# /usr/bin/time -v dictys_helper split_bam.sh bams.bam bams --section "CB:Z:" --ref_expression expression.tsv.gz
# rm bams.bam
# Out:
# 	Command being timed: "dictys_helper split_bam.sh bams.bam bams --section CB:Z: --ref_expression expression.tsv.gz"
# 	User time (seconds): 1097.66
# 	System time (seconds): 187.20
# 	Percent of CPU this job got: 60%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 35:15.91
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 8777140
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 18
# 	Minor (reclaiming a frame) page faults: 85689530
# 	Voluntary context switches: 17729036
# 	Involuntary context switches: 5392
# 	Swaps: 0
# 	File system inputs: 122180616
# 	File system outputs: 128438344
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %% [markdown]
# ### subsets & subsets.txt
# * subsets.txt: Names of cell subsets. For each cell subset, a GRN is reconstructed.
# * subsets: Folder containing one subfolder for each cell subset as in `subsets.txt`. Each subfolder contains two files:
#     - names_rna.txt: Names of cells that belong to this subset and have transcriptome measurement
#     - names_atac.txt: Names of cells that belong to this subset and have chromatin accessibility measurement
#     - For joint measurements of RNA and ATAC, these two files should be identical in every folder.
#
# Option 1: download the clustering from 10x "Secondary analysis outputs (DIR)":

# %%
# %%bash
# cd ./data
# wget -q -o /dev/null https://cf.10xgenomics.com/samples/cell-arc/1.0.0/pbmc_granulocyte_sorted_3k/pbmc_granulocyte_sorted_3k_analysis.tar.gz
# #Extract cell names for each cluster
# tar xf pbmc_granulocyte_sorted_3k_analysis.tar.gz
# mv analysis/clustering/gex/graphclust/clusters.csv clusters.csv
# rm -Rf pbmc_granulocyte_sorted_3k_analysis.tar.gz analysis

# %% [markdown]
# Option 2: cluster with other softwares (here [scanpy](https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html) below).
#
# **Note**:
# * The cell below can be hidden if you use a renderer other than jupyter (e.g. github).
# * If you don't have scanpy installed, the kernel would automatically restart to finish scanpy installation. Please continue by running this cell again for clustering.

# %% [markdown]
# #Installs scanpy if not present
# a=!pip show scanpy &> /dev/null; echo $?
# a=''.join(a)
# if a=='0':
# 	print('Scanpy found. Continuing notebook execution.')
# elif a=='1':
# 	a=!pip install 'scanpy[leiden]'; echo $?
# 	a=''.join(a)
# 	if a!='0':
# 		raise RuntimeError('Installing scanpy failed.')
# 	print('Installing scanpy completed. Restarting kernel. Please continue from here.')
# 	import os
# 	os._exit(00)
# else:
# 	raise ValueError('Unknown return for: pip show scanpy')
#
# #Clustering with scanpy
# import numpy as np
# import pandas as pd
# import scanpy as sc
# adata = sc.read_10x_mtx('../data/filtered_feature_bc_matrix/',var_names='gene_symbols',cache=False)
# adata.var_names_make_unique()
# sc.pp.filter_cells(adata, min_genes=200)
# sc.pp.filter_genes(adata, min_cells=3)
# adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
# sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
# sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
# sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')
# adata = adata[adata.obs.n_genes_by_counts < 6000, :]
# adata = adata[adata.obs.pct_counts_mt < 20, :]
# sc.pp.normalize_total(adata, target_sum=1e4)
# sc.pp.log1p(adata)
# sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
# sc.pl.highly_variable_genes(adata)
# adata.raw = adata
# adata = adata[:, adata.var.highly_variable]
# sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])
# sc.pp.scale(adata, max_value=10)
# sc.tl.pca(adata, svd_solver='arpack')
# sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
# sc.tl.leiden(adata)
# adata.obs.leiden.to_csv('../data/clusters.csv',header=['Cluster'],index=True,index_label='Barcode')

# %% [markdown]
# Finally, reformat clusters.csv for input:

# %%
# %%bash
# cd ./data
# subsets="$(tail -n +2 clusters.csv | awk -F , '{print $2}' | sort -u)"
# echo "$subsets" | awk '{print "Subset"$1}' > subsets.txt
# for x in $subsets; do
# 	mkdir -p "subsets/Subset$x"
# 	grep ",$x"'$' clusters.csv | awk -F , '{print $1}' > "subsets/Subset$x/names_rna.txt"
# 	# RNA and ATAC barcodes are the same for joint quantifications
# 	cp "subsets/Subset$x/names_rna.txt" "subsets/Subset$x/names_atac.txt"
# done
# rm clusters.csv

# %% [markdown]
# ### Other files
# Motif, reference genome, gene transcriptional start site

# %%
# %%bash
# cd ./data
#
# # Motifs (file motifs.motif)
# # Option 1: from HOCOMOCO (https://hocomoco11.autosome.org/)
# wget -q -o /dev/null -O motifs.motif 'https://hocomoco11.autosome.org/final_bundle/hocomoco11/full/HUMAN/mono/HOCOMOCOv11_full_HUMAN_mono_homer_format_0.0001.motif'
# # Option 2: from HOMER
# #dictys_helper motif_homer.sh > motifs.motif
# # Option 3: provide your custom motifs

# %%
# !head -n 18 ./data/motifs.motif
# Out:
# >dKhGCGTGh	AHR_HUMAN.H11MO.0.B	3.3775000000000004
# 0.262728374765856	0.1227600511842322	0.362725638699551	0.25178593535036087
# 0.07633328991810645	0.08258130543118362	0.22593295481662123	0.6151524498340887
# 0.14450570038747923	0.28392173880411337	0.13815442099009081	0.4334181398183167
# 0.023935814057894068	0.016203821748029118	0.9253278681170539	0.03453249607702277
# 0.007919544273173793	0.953597675415874	0.017308392078009837	0.021174388232942286
# 0.02956192959210962	0.012890110758086997	0.9474192747166682	0.010128684933135217
# 0.007919544273173797	0.029561929592109615	0.012337825593096645	0.9501807005416201
# 0.007919544273173793	0.007919544273173793	0.9762413671804787	0.007919544273173793
# 0.27886589130660366	0.4285328543459993	0.10955683916661985	0.18304441518077724
# >hnnGGWWnddWWGGdbWh	AIRE_HUMAN.H11MO.0.C	5.64711
# 0.38551919443239085	0.2604245534178759	0.1353299124033618	0.21872633974637148
# 0.18745267949274294	0.18745267949274294	0.14575446582123766	0.4793401751932764
# 0.14575446582123777	0.14575446582123777	0.2083017863284958	0.5001892820290286
# 0.0623580384782284	0.020659824806723626	0.8337749914010671	0.08320714531398087
# 0.020659824806723633	0.020659824806723633	0.7712276708938095	0.18745267949274314
# 0.3125473205072573	0.062358038478228406	0.04150893164247602	0.5835857093720382
# 0.37509464101451423	0.10405625214973326	0.04150893164247601	0.4793401751932766

# %%
# %%bash
# cd ./data
# # Reference genome (folder genome)
# # Note: You need the same reference genome version with chromatin accessibility reads
# # Option 1: download genome from HOMER
# dictys_helper genome_homer.sh hg38 genome
# # Option 2: provide your custom genome
# Out:
# Process is interrupted.

# %%
# %%bash
# ls -h1s ./data/genome | head
# Out:
# total 4.3G
# 113K annotations
#  64K chrom.sizes
# 3.7G genome.fa
# 4.2M hg38.aug
#  51M hg38.basic.annotation
# 258M hg38.full.annotation
# 272K hg38.miRNA
# 233M hg38.repeats
#  16M hg38.rna

# %%
# %%bash
# cd ./data
# # Bed file for TSS (file gene.bed)
# # Download gtf file from ensembl
# #wget -q -o /dev/null -O gene.gtf.gz http://ftp.ensembl.org/pub/release-107/gtf/homo_sapiens/Homo_sapiens.GRCh38.107.gtf.gz
# gunzip gene.gtf.gz
# # Convert to bed
# dictys_helper gene_gtf.sh gene.gtf gene.bed
# rm gene.gtf

# %%
# !head ./data/gene.bed
# Out:
# chr1	11869	14409	DDX11L1	.	+
# chr1	14404	29570	WASH7P	.	-
# chr1	17369	17436	MIR6859-1	.	-
# chr1	29554	31109	MIR1302-2HG	.	+
# chr1	30366	30503	MIR1302-2	.	+
# chr1	34554	36081	FAM138A	.	-
# chr1	52473	53312	OR4G4P	.	+
# chr1	57598	64116	OR4G11P	.	+
# chr1	65419	71585	OR4F5	.	+
# chr1	131025	134836	CICP27	.	+

# %% [markdown]
# ### Clean up

# %%
# !rm -Rf ./data/filtered_feature_bc_matrix

# %% [markdown]
# ## 2. Network inference configuration
# ### Generate configurations
# Please adjust them for your own machine and dataset

# %%
pwd
# Out:
# '/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k'

# %%
# %%bash
# # Generate configuration template
# rm -Rf ./makefiles
# mkdir ./makefiles
# cd ./makefiles
# dictys_helper makefile_template.sh common.mk config.mk env_none.mk static.mk
#
# # Update configurations, such as:
# # DEVICE: pytorch device, e.g. cpu, cuda:0. If you do not have a GPU, use 'cpu' and expect LONG computing time.
# # GENOME_MACS2: effective genome size for macs2. See https://deeptools.readthedocs.io/en/develop/content/feature/effectiveGenomeSize.html
# # JOINT: whether dataset is joint profiling of RNA and ATAC.
# # Other configurations include quality control thresholds, number of threads in each job, number of hidden confounders, etc.
# # They can be obtained in the full-multiome tutorial.
# dictys_helper makefile_update.py ../makefiles/config.mk '{"DEVICE": "cpu", "GENOME_MACS2": "hs", "JOINT": "1"}'

# %%
# !cat ./makefiles/config.mk
# Out:
# # Lingfei Wang, 2022. All rights reserved.
# #This file contains parameters for whole run and individual steps to be edited for your dataset
# #This file should be edited to configure the run
# #This file should NOT be directly used for any run with `makefile -f`
#
# ############################################################
# # Run environment settings
# ############################################################
# #Which environment to use, corresponding to env_$(ENVMODE).mk file
# ENVMODE=none
# #Maximum number of CPU threads for each job
# #This is only nominated and passed through to other softwares without any guarantee.
# NTH=4
# #Device name for pyro/pytorch
# #Note: cuda devices other than cuda:0 could be incompatible with singularity environment
# DEVICE=cpu
#
# ############################################################
# # Dataset settings
# ############################################################
#
# #Genome size for Macs2, accept shortcuts like mm & hs
# GENOME_MACS2=hs
# #Whether dataset is joint profiling of RNA & ATAC of same cell. Separate measurements of two modalities in different cells: 0. Joint measurements: 1.
# JOINT=1
#
# #######################################################################################
# # Parameters of individual steps shared by cell-type specific and dynamic GRN inference
# #######################################################################################
#
# PARAMS-PREPROC-QC_READS:=50 10 0 200 100 0
# PARAMS-CHROMATIN-MACS2:=$(GENOME_MACS2)
# PARAMS-CHROMATIN-BINLINKING:=20
# KPARAMS-PREPROC-SELECTSC_RNA:=
# KPARAMS-PREPROC-QC_READS:=
# KPARAMS-PREPROC-SELECTSC_ATAC:=
# KPARAMS-CHROMATIN-MACS2:=--nth $(NTH)
# KPARAMS-CHROMATIN-WELLINGTON:=--nth $(NTH)
# KPARAMS-CHROMATIN-HOMER:=--nth $(NTH)
# KPARAMS-CHROMATIN-BINDING:=
# KPARAMS-CHROMATIN-TSSDIST:=
# KPARAMS-CHROMATIN-LINKING:=
# KPARAMS-CHROMATIN-BINLINKING:=
# KPARAMS-NETWORK-RECONSTRUCT:=--device $(DEVICE) --nth $(NTH)
# KPARAMS-NETWORK-INDIRECT:=--nth $(NTH)
# KPARAMS-NETWORK-NORMALIZE:=--nth $(NTH)
# KPARAMS-NETWORK-TOFILE:=$(KPARAMS-NETWORK-TOFILE_EXTRA)
#
# #######################################################################################
# # Parameters of individual steps only in dynamic GRN inference
# #######################################################################################
#
# PARAMS-DYNAMIC-SUBSETS_RNA=1000 875 0.05
# PARAMS-DYNAMIC-SUBSETS_ATAC=$(firstword $(PARAMS-DYNAMIC-SUBSETS_RNA))

# %% [markdown]
# ### Validate input data

# %%
# %%bash
# /usr/bin/time -v cd . &&  /usr/bin/time -v dictys_helper makefile_check.py
# Out:
# 	Command being timed: "cd ."
# 	User time (seconds): 0.00
# 	System time (seconds): 0.00
# 	Percent of CPU this job got: 50%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 0:00.00
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 3328
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 0
# 	Minor (reclaiming a frame) page faults: 189
# 	Voluntary context switches: 8
# 	Involuntary context switches: 0
# 	Swaps: 0
# 	File system inputs: 8
# 	File system outputs: 0
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0
# WARNING:root:Chromosomes not found in reference genome: chrGL000194.1,chrMT
# WARNING:root:Cannot find dynamic.mk or traj_node.h5. Skipping dynamic network inference checks.
# Joint profile: True
# Found 2714 cells with RNA profile
# Found 24036 genes with RNA profile
# Found 2714 cells with ATAC profile
# Found 769 motifs
# Found 678 TFs
# Found 461 TFs in current dataset
# Missing 217 TFs in current dataset: ANDR,AP2A,AP2B,AP2C,AP2D,ARI3A,ARI5B,ATF6A,BARH1,BARH2,BC11A,BHA15,BHE22,BHE23,BHE40,BHE41,BMAL1,BRAC,BSH,COE1,COT1,COT2,CR3L1,CR3L2,ERR1,ERR2,ERR3,EVI1,GCR,HEN1,HMBX1,HME1,HME2,HNF6,HTF4,HXA1,HXA10,HXA11,HXA13,HXA2,HXA5,HXA7,HXA9,HXB1,HXB13,HXB2,HXB3,HXB4,HXB6,HXB7,HXB8,HXC10,HXC11,HXC12,HXC13,HXC6,HXC8,HXC9,HXD10,HXD11,HXD12,HXD13,HXD3,HXD4,HXD8,HXD9,ITF2,KAISO,MCR,MGAP,MLXPL,MYBA,MYBB,NDF1,NDF2,NF2L1,NF2L2,NFAC1,NFAC2,NFAC3,NFAC4,NGN2,NKX21,NKX22,NKX23,NKX25,NKX28,NKX31,NKX32,NKX61,NKX62,ONEC2,ONEC3,OZF,P53,P5F1B,P63,P73,PEBB,PHX2A,PHX2B,PIT1,PKNX1,PLAL1,PO2F1,PO2F2,PO2F3,PO3F1,PO3F2,PO3F3,PO3F4,PO4F1,PO4F2,PO4F3,PO5F1,PO6F1,PO6F2,PRD14,PRGR,RHXF1,RORG,RX,SMCA1,SMCA5,SRBP1,SRBP2,STA5A,STA5B,STF1,SUH,TF2LX,TF65,TF7L1,TF7L2,TFE2,THA,THA11,THB,TWST1,TYY1,TYY2,UBIP1,UNC4,Z324A,Z354A,ZBT14,ZBT17,ZBT18,ZBT48,ZBT49,ZBT7A,ZBT7B,ZEP1,ZEP2,ZF64A,ZKSC1,ZKSC3,ZN121,ZN134,ZN136,ZN140,ZN143,ZN148,ZN214,ZN219,ZN232,ZN250,ZN257,ZN260,ZN263,ZN264,ZN274,ZN281,ZN282,ZN317,ZN320,ZN322,ZN329,ZN331,ZN333,ZN335,ZN341,ZN350,ZN382,ZN384,ZN394,ZN410,ZN418,ZN423,ZN436,ZN449,ZN467,ZN490,ZN502,ZN524,ZN528,ZN547,ZN549,ZN554,ZN563,ZN582,ZN586,ZN589,ZN652,ZN667,ZN680,ZN708,ZN713,ZN740,ZN768,ZN770,ZN784,ZN816,ZSC16,ZSC22,ZSC31,ZSCA4
# Found 23533 genes with TSS information
# 	Command being timed: "dictys_helper makefile_check.py"
# 	User time (seconds): 17.75
# 	System time (seconds): 5.53
# 	Percent of CPU this job got: 54%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 0:42.88
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 7923800
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 6
# 	Minor (reclaiming a frame) page faults: 4280792
# 	Voluntary context switches: 65301
# 	Involuntary context switches: 791
# 	Swaps: 0
# 	File system inputs: 6408392
# 	File system outputs: 0
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %% [markdown]
# ## 3. Network inference
# * **This step can take a day or longer**. You are strongly suggested to use a GPU. If it takes over a day, see [FAQ](https://github.com/pinellolab/dictys#faq) to improve speed.
# * Please adjust `-j n_jobs` for your machine. The total thread count is n_jobs*n_threads. By default n_threads=4.

# %%
import os
print(os.cpu_count())
# Out:
# 32

# %%
# %memit
# Out:
# peak memory: 74.64 MiB, increment: 0.00 MiB

# %%
# %%bash
# cd .;
# /usr/bin/time -v dictys_helper network_inference.sh -j 32 -J 1 static
# Out:
# mkdir -p tmp_static/Subset1/
# cp data/subsets/Subset1/names_rna.txt tmp_static/Subset1/names_rna.txt
# mkdir -p tmp_static/Subset2/
# mkdir -p tmp_static/Subset3/
# cp data/subsets/Subset2/names_rna.txt tmp_static/Subset2/names_rna.txt
# cp data/subsets/Subset3/names_rna.txt tmp_static/Subset3/names_rna.txt
# mkdir -p tmp_static/Subset4/
# mkdir -p tmp_static/Subset5/
# cp data/subsets/Subset4/names_rna.txt tmp_static/Subset4/names_rna.txt
# cp data/subsets/Subset5/names_rna.txt tmp_static/Subset5/names_rna.txt
# mkdir -p tmp_static/Subset6/
# cp data/subsets/Subset6/names_rna.txt tmp_static/Subset6/names_rna.txt
# mkdir -p tmp_static/Subset7/
# cp data/subsets/Subset7/names_rna.txt tmp_static/Subset7/names_rna.txt
# mkdir -p tmp_static/Subset8/
# cp data/subsets/Subset8/names_rna.txt tmp_static/Subset8/names_rna.txt
# mkdir -p tmp_static/Subset9/
# cp data/subsets/Subset9/names_rna.txt tmp_static/Subset9/names_rna.txt
# cp tmp_static/Subset1/names_rna.txt tmp_static/Subset1/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset1/names_rna.txt tmp_static/Subset1/expression0.tsv.gz
# cp tmp_static/Subset2/names_rna.txt tmp_static/Subset2/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset2/names_rna.txt tmp_static/Subset2/expression0.tsv.gz
# cp tmp_static/Subset3/names_rna.txt tmp_static/Subset3/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset3/names_rna.txt tmp_static/Subset3/expression0.tsv.gz
# cp tmp_static/Subset4/names_rna.txt tmp_static/Subset4/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset4/names_rna.txt tmp_static/Subset4/expression0.tsv.gz
# cp tmp_static/Subset5/names_rna.txt tmp_static/Subset5/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset5/names_rna.txt tmp_static/Subset5/expression0.tsv.gz
# cp tmp_static/Subset6/names_rna.txt tmp_static/Subset6/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset6/names_rna.txt tmp_static/Subset6/expression0.tsv.gz
# cp tmp_static/Subset7/names_rna.txt tmp_static/Subset7/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset7/names_rna.txt tmp_static/Subset7/expression0.tsv.gz
# cp tmp_static/Subset8/names_rna.txt tmp_static/Subset8/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset8/names_rna.txt tmp_static/Subset8/expression0.tsv.gz
# cp tmp_static/Subset9/names_rna.txt tmp_static/Subset9/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset9/names_rna.txt tmp_static/Subset9/expression0.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset8/expression0.tsv.gz tmp_static/Subset8/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset6/expression0.tsv.gz tmp_static/Subset6/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset7/expression0.tsv.gz tmp_static/Subset7/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset9/expression0.tsv.gz tmp_static/Subset9/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset5/expression0.tsv.gz tmp_static/Subset5/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset4/expression0.tsv.gz tmp_static/Subset4/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset8/expression.tsv.gz tmp_static/Subset8/names_atac0.txt tmp_static/Subset8/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset1/expression0.tsv.gz tmp_static/Subset1/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset2/expression0.tsv.gz tmp_static/Subset2/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset3/expression0.tsv.gz tmp_static/Subset3/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset8/names_atac.txt data/bams tmp_static/Subset8/reads.bam tmp_static/Subset8/reads.bai tmp_static/Subset8/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset6/expression.tsv.gz tmp_static/Subset6/names_atac0.txt tmp_static/Subset6/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset7/expression.tsv.gz tmp_static/Subset7/names_atac0.txt tmp_static/Subset7/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset6/names_atac.txt data/bams tmp_static/Subset6/reads.bam tmp_static/Subset6/reads.bai tmp_static/Subset6/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset5/expression.tsv.gz tmp_static/Subset5/names_atac0.txt tmp_static/Subset5/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset9/expression.tsv.gz tmp_static/Subset9/names_atac0.txt tmp_static/Subset9/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset7/names_atac.txt data/bams tmp_static/Subset7/reads.bam tmp_static/Subset7/reads.bai tmp_static/Subset7/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset4/expression.tsv.gz tmp_static/Subset4/names_atac0.txt tmp_static/Subset4/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset1/expression.tsv.gz tmp_static/Subset1/names_atac0.txt tmp_static/Subset1/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset2/expression.tsv.gz tmp_static/Subset2/names_atac0.txt tmp_static/Subset2/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset9/names_atac.txt data/bams tmp_static/Subset9/reads.bam tmp_static/Subset9/reads.bai tmp_static/Subset9/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset5/names_atac.txt data/bams tmp_static/Subset5/reads.bam tmp_static/Subset5/reads.bai tmp_static/Subset5/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset4/names_atac.txt data/bams tmp_static/Subset4/reads.bam tmp_static/Subset4/reads.bai tmp_static/Subset4/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset1/names_atac.txt data/bams tmp_static/Subset1/reads.bam tmp_static/Subset1/reads.bai tmp_static/Subset1/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset2/names_atac.txt data/bams tmp_static/Subset2/reads.bam tmp_static/Subset2/reads.bai tmp_static/Subset2/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset3/expression.tsv.gz tmp_static/Subset3/names_atac0.txt tmp_static/Subset3/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset3/names_atac.txt data/bams tmp_static/Subset3/reads.bam tmp_static/Subset3/reads.bai tmp_static/Subset3/peaks.bed hs
# [bam_sort_core] merging from 0 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:08:18:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset8/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset8/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:08:18: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:08:18: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:08:18: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:08:18: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:08:18: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:08:21:  1000000
# INFO  @ Thu, 01 Aug 2024 17:08:24:  2000000
# INFO  @ Thu, 01 Aug 2024 17:08:27: 2957766 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:08:27: #1 tag size is determined as 49 bps
# INFO  @ Thu, 01 Aug 2024 17:08:27: #1 tag size = 49.0
# INFO  @ Thu, 01 Aug 2024 17:08:27: #1  total tags in treatment: 2957766
# INFO  @ Thu, 01 Aug 2024 17:08:27: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:08:27: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:08:27: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:08:27: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:08:27: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:08:27: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:08:27: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:08:27: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:08:27: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:08:31: access pq hash for 6868406 times
# INFO  @ Thu, 01 Aug 2024 17:08:31: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:08:47: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:08:48: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:08:48: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:08:48: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset8/reads.bam tmp_static/Subset8/reads.bai tmp_static/Subset8/peaks.bed tmp_static/Subset8/footprints.bed
# [bam_sort_core] merging from 0 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:09:08:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset9/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset9/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:09:08: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:09:08: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:09:08: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:09:08: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:09:08: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:09:11:  1000000
# INFO  @ Thu, 01 Aug 2024 17:09:14:  2000000
# INFO  @ Thu, 01 Aug 2024 17:09:17:  3000000
# INFO  @ Thu, 01 Aug 2024 17:09:20: 3860901 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:09:20: #1 tag size is determined as 49 bps
# INFO  @ Thu, 01 Aug 2024 17:09:20: #1 tag size = 49.0
# INFO  @ Thu, 01 Aug 2024 17:09:20: #1  total tags in treatment: 3860901
# INFO  @ Thu, 01 Aug 2024 17:09:20: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:09:20: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:09:20: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:09:20: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:09:20: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:09:20: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:09:20: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:09:20: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:09:20: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:09:24: access pq hash for 8985502 times
# INFO  @ Thu, 01 Aug 2024 17:09:24: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:09:45: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:09:45: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:09:45: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:09:45: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset9/reads.bam tmp_static/Subset9/reads.bai tmp_static/Subset9/peaks.bed tmp_static/Subset9/footprints.bed
# [bam_sort_core] merging from 1 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:09:37:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset6/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset6/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:09:37: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:09:37: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:09:37: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:09:37: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:09:37: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:09:40:  1000000
# INFO  @ Thu, 01 Aug 2024 17:09:43:  2000000
# INFO  @ Thu, 01 Aug 2024 17:09:46:  3000000
# INFO  @ Thu, 01 Aug 2024 17:09:49:  4000000
# INFO  @ Thu, 01 Aug 2024 17:09:52: 4693961 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:09:52: #1 tag size is determined as 49 bps
# INFO  @ Thu, 01 Aug 2024 17:09:52: #1 tag size = 49.0
# INFO  @ Thu, 01 Aug 2024 17:09:52: #1  total tags in treatment: 4693961
# INFO  @ Thu, 01 Aug 2024 17:09:52: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:09:52: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:09:52: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:09:52: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:09:52: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:09:52: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:09:52: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:09:52: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:09:52: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:09:58: access pq hash for 10106809 times
# INFO  @ Thu, 01 Aug 2024 17:09:58: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:10:16: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:10:17: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:10:17: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:10:17: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset6/reads.bam tmp_static/Subset6/reads.bai tmp_static/Subset6/peaks.bed tmp_static/Subset6/footprints.bed
# [bam_sort_core] merging from 1 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:09:55:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset7/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset7/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:09:55: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:09:55: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:09:55: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:09:55: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:09:55: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:09:58:  1000000
# INFO  @ Thu, 01 Aug 2024 17:10:01:  2000000
# INFO  @ Thu, 01 Aug 2024 17:10:04:  3000000
# INFO  @ Thu, 01 Aug 2024 17:10:07:  4000000
# INFO  @ Thu, 01 Aug 2024 17:10:11:  5000000
# INFO  @ Thu, 01 Aug 2024 17:10:14:  6000000
# INFO  @ Thu, 01 Aug 2024 17:10:15: 6311723 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:10:15: #1 tag size is determined as 49 bps
# INFO  @ Thu, 01 Aug 2024 17:10:15: #1 tag size = 49.0
# INFO  @ Thu, 01 Aug 2024 17:10:15: #1  total tags in treatment: 6311723
# INFO  @ Thu, 01 Aug 2024 17:10:15: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:10:15: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:10:15: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:10:15: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:10:15: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:10:15: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:10:15: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:10:15: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:10:15: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:10:23: access pq hash for 13789663 times
# INFO  @ Thu, 01 Aug 2024 17:10:23: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:10:43: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:10:43: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:10:43: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:10:43: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset7/reads.bam tmp_static/Subset7/reads.bai tmp_static/Subset7/peaks.bed tmp_static/Subset7/footprints.bed
# [bam_sort_core] merging from 1 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:10:06:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset5/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset5/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:10:06: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:10:06: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:10:06: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:10:06: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:10:06: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:10:09:  1000000
# INFO  @ Thu, 01 Aug 2024 17:10:12:  2000000
# INFO  @ Thu, 01 Aug 2024 17:10:15:  3000000
# INFO  @ Thu, 01 Aug 2024 17:10:18:  4000000
# INFO  @ Thu, 01 Aug 2024 17:10:21:  5000000
# INFO  @ Thu, 01 Aug 2024 17:10:22: 5346533 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:10:22: #1 tag size is determined as 49 bps
# INFO  @ Thu, 01 Aug 2024 17:10:22: #1 tag size = 49.0
# INFO  @ Thu, 01 Aug 2024 17:10:22: #1  total tags in treatment: 5346533
# INFO  @ Thu, 01 Aug 2024 17:10:22: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:10:22: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:10:22: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:10:22: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:10:22: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:10:22: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:10:22: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:10:22: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:10:22: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:10:29: access pq hash for 11250699 times
# INFO  @ Thu, 01 Aug 2024 17:10:29: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:10:50: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:10:50: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:10:50: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:10:50: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset5/reads.bam tmp_static/Subset5/reads.bai tmp_static/Subset5/peaks.bed tmp_static/Subset5/footprints.bed
# [bam_sort_core] merging from 2 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:12:08:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset2/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset2/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:12:08: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:12:08: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:12:08: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:12:08: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:12:08: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:12:11:  1000000
# INFO  @ Thu, 01 Aug 2024 17:12:14:  2000000
# INFO  @ Thu, 01 Aug 2024 17:12:18:  3000000
# INFO  @ Thu, 01 Aug 2024 17:12:21:  4000000
# INFO  @ Thu, 01 Aug 2024 17:12:24:  5000000
# INFO  @ Thu, 01 Aug 2024 17:12:28:  6000000
# INFO  @ Thu, 01 Aug 2024 17:12:31:  7000000
# INFO  @ Thu, 01 Aug 2024 17:12:34:  8000000
# INFO  @ Thu, 01 Aug 2024 17:12:37:  9000000
# INFO  @ Thu, 01 Aug 2024 17:12:37: 9104121 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:12:37: #1 tag size is determined as 49 bps
# INFO  @ Thu, 01 Aug 2024 17:12:37: #1 tag size = 49.0
# INFO  @ Thu, 01 Aug 2024 17:12:37: #1  total tags in treatment: 9104121
# INFO  @ Thu, 01 Aug 2024 17:12:37: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:12:37: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:12:37: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:12:37: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:12:37: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:12:37: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:12:37: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:12:37: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:12:37: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:12:48: access pq hash for 17953568 times
# INFO  @ Thu, 01 Aug 2024 17:12:48: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:13:12: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:13:13: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:13:13: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:13:13: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset2/reads.bam tmp_static/Subset2/reads.bai tmp_static/Subset2/peaks.bed tmp_static/Subset2/footprints.bed
# [bam_sort_core] merging from 2 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:12:17:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset1/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset1/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:12:17: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:12:17: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:12:17: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:12:17: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:12:17: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:12:20:  1000000
# INFO  @ Thu, 01 Aug 2024 17:12:23:  2000000
# INFO  @ Thu, 01 Aug 2024 17:12:26:  3000000
# INFO  @ Thu, 01 Aug 2024 17:12:30:  4000000
# INFO  @ Thu, 01 Aug 2024 17:12:33:  5000000
# INFO  @ Thu, 01 Aug 2024 17:12:36:  6000000
# INFO  @ Thu, 01 Aug 2024 17:12:39:  7000000
# INFO  @ Thu, 01 Aug 2024 17:12:42:  8000000
# INFO  @ Thu, 01 Aug 2024 17:12:45:  9000000
# INFO  @ Thu, 01 Aug 2024 17:12:48:  10000000
# INFO  @ Thu, 01 Aug 2024 17:12:51: 10971622 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:12:51: #1 tag size is determined as 49 bps
# INFO  @ Thu, 01 Aug 2024 17:12:51: #1 tag size = 49.0
# INFO  @ Thu, 01 Aug 2024 17:12:51: #1  total tags in treatment: 10971622
# INFO  @ Thu, 01 Aug 2024 17:12:51: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:12:51: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:12:51: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:12:51: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:12:51: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:12:51: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:12:51: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:12:51: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:12:51: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:13:05: access pq hash for 21638339 times
# INFO  @ Thu, 01 Aug 2024 17:13:05: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:13:27: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:13:27: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:13:27: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:13:27: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset1/reads.bam tmp_static/Subset1/reads.bai tmp_static/Subset1/peaks.bed tmp_static/Subset1/footprints.bed
# [bam_sort_core] merging from 2 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:12:08:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset4/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset4/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:12:08: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:12:08: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:12:08: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:12:08: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:12:08: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:12:11:  1000000
# INFO  @ Thu, 01 Aug 2024 17:12:14:  2000000
# INFO  @ Thu, 01 Aug 2024 17:12:17:  3000000
# INFO  @ Thu, 01 Aug 2024 17:12:20:  4000000
# INFO  @ Thu, 01 Aug 2024 17:12:23:  5000000
# INFO  @ Thu, 01 Aug 2024 17:12:27:  6000000
# INFO  @ Thu, 01 Aug 2024 17:12:30:  7000000
# INFO  @ Thu, 01 Aug 2024 17:12:34:  8000000
# INFO  @ Thu, 01 Aug 2024 17:12:37:  9000000
# INFO  @ Thu, 01 Aug 2024 17:12:40:  10000000
# INFO  @ Thu, 01 Aug 2024 17:12:42: 10670307 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:12:42: #1 tag size is determined as 49 bps
# INFO  @ Thu, 01 Aug 2024 17:12:42: #1 tag size = 49.0
# INFO  @ Thu, 01 Aug 2024 17:12:42: #1  total tags in treatment: 10670307
# INFO  @ Thu, 01 Aug 2024 17:12:42: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:12:42: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:12:42: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:12:42: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:12:42: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:12:42: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:12:42: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:12:42: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:12:42: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:12:56: access pq hash for 23710636 times
# INFO  @ Thu, 01 Aug 2024 17:12:56: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:13:30: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:13:31: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:13:31: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:13:31: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset4/reads.bam tmp_static/Subset4/reads.bai tmp_static/Subset4/peaks.bed tmp_static/Subset4/footprints.bed
# [bam_sort_core] merging from 2 files and 4 in-memory blocks...
# INFO  @ Thu, 01 Aug 2024 17:12:21:
# # Command line: callpeak -t /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset3/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/tmp_static/Subset3/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Thu, 01 Aug 2024 17:12:21: #1 read tag files...
# INFO  @ Thu, 01 Aug 2024 17:12:21: #1 read treatment tags...
# DEBUG @ Thu, 01 Aug 2024 17:12:21: Testing format BAM
# INFO  @ Thu, 01 Aug 2024 17:12:21: Detected format is: BAM
# INFO  @ Thu, 01 Aug 2024 17:12:21: * Input file is gzipped.
# INFO  @ Thu, 01 Aug 2024 17:12:24:  1000000
# INFO  @ Thu, 01 Aug 2024 17:12:27:  2000000
# INFO  @ Thu, 01 Aug 2024 17:12:30:  3000000
# INFO  @ Thu, 01 Aug 2024 17:12:34:  4000000
# INFO  @ Thu, 01 Aug 2024 17:12:37:  5000000
# INFO  @ Thu, 01 Aug 2024 17:12:40:  6000000
# INFO  @ Thu, 01 Aug 2024 17:12:43:  7000000
# INFO  @ Thu, 01 Aug 2024 17:12:46:  8000000
# INFO  @ Thu, 01 Aug 2024 17:12:50:  9000000
# INFO  @ Thu, 01 Aug 2024 17:12:53:  10000000
# INFO  @ Thu, 01 Aug 2024 17:12:55: 10595817 reads have been read.
# INFO  @ Thu, 01 Aug 2024 17:12:55: #1 tag size is determined as 48 bps
# INFO  @ Thu, 01 Aug 2024 17:12:55: #1 tag size = 48.0
# INFO  @ Thu, 01 Aug 2024 17:12:55: #1  total tags in treatment: 10595817
# INFO  @ Thu, 01 Aug 2024 17:12:55: #1 finished!
# INFO  @ Thu, 01 Aug 2024 17:12:55: #2 Build Peak Model...
# INFO  @ Thu, 01 Aug 2024 17:12:55: #2 Skipped...
# INFO  @ Thu, 01 Aug 2024 17:12:55: #2 Use 150 as fragment length
# INFO  @ Thu, 01 Aug 2024 17:12:55: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Thu, 01 Aug 2024 17:12:55: #3 Call peaks...
# INFO  @ Thu, 01 Aug 2024 17:12:55: #3 Going to call summits inside each peak ...
# INFO  @ Thu, 01 Aug 2024 17:12:55: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Thu, 01 Aug 2024 17:12:55: Start to calculate pvalue stat...
# DEBUG @ Thu, 01 Aug 2024 17:13:09: access pq hash for 22343420 times
# INFO  @ Thu, 01 Aug 2024 17:13:09: #3 Call peaks for each chromosome...
# INFO  @ Thu, 01 Aug 2024 17:13:43: #4 Write output xls file... 04_peaks.xls
# INFO  @ Thu, 01 Aug 2024 17:13:44: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Thu, 01 Aug 2024 17:13:44: #4 Write summits bed file... 04_summits.bed
# INFO  @ Thu, 01 Aug 2024 17:13:44: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset3/reads.bam tmp_static/Subset3/reads.bai tmp_static/Subset3/peaks.bed tmp_static/Subset3/footprints.bed
# Reading BED File...
# Calculating footprints...
# Waiting for the last 30 jobs to finish...
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin homer --nth 4 tmp_static/Subset8/footprints.bed data/motifs.motif data/genome tmp_static/Subset8/expression.tsv.gz tmp_static/Subset8/motifs.bed tmp_static/Subset8/wellington.tsv.gz tmp_static/Subset8/homer.tsv.gz
#
# 	Position file = 14-reform-split/aaaac
# 	Genome = /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
# 	Output Directory = 15-motifscan/aaaac
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 5768
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 5768
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 20 (avg size of targets)
# 	Background files for 20 bp fragments found.
# 	Custom genome sequence directory: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
#
# 	Extracting sequences from file: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa
# 	Looking for peak sequences in a single file (/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa)
# 	Extracting 563 sequences from chr1
# 	Extracting 211 sequences from chr10
# 	Extracting 351 sequences from chr11
# 	Extracting 320 sequences from chr12
# 	Extracting 109 sequences from chr13
# 	Extracting 218 sequences from chr14
# 	Extracting 164 sequences from chr15
# 	Extracting 283 sequences from chr16
# 	Extracting 397 sequences from chr17
# 	Extracting 66 sequences from chr18
# 	Extracting 568 sequences from chr19
# 	Extracting 369 sequences from chr2
# 	Extracting 122 sequences from chr20
# 	Extracting 85 sequences from chr21
# 	Extracting 131 sequences from chr22
# 	Extracting 261 sequences from chr3
# 	Extracting 198 sequences from chr4
# 	Extracting 207 sequences from chr5
# 	Extracting 316 sequences from chr6
# 	Extracting 285 sequences from chr7
# 	Extracting 162 sequences from chr8
# 	Extracting 246 sequences from chr9
# 	Extracting 109 sequences from chrX
#
#
# 	Reading input files...
# 	5741 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaad
# 	Genome = /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
# 	Output Directory = 15-motifscan/aaaad
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 5767
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 5767
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 19 (avg size of targets)
# 	Background files for 19 bp fragments found.
# 	Custom genome sequence directory: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
#
# 	Extracting sequences from file: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa
# 	Looking for peak sequences in a single file (/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa)
# 	Extracting 613 sequences from chr1
# 	Extracting 221 sequences from chr10
# 	Extracting 289 sequences from chr11
# 	Extracting 303 sequences from chr12
# 	Extracting 102 sequences from chr13
# 	Extracting 204 sequences from chr14
# 	Extracting 149 sequences from chr15
# 	Extracting 286 sequences from chr16
# 	Extracting 368 sequences from chr17
# 	Extracting 81 sequences from chr18
# 	Extracting 546 sequences from chr19
# 	Extracting 373 sequences from chr2
# 	Extracting 133 sequences from chr20
# 	Extracting 101 sequences from chr21
# 	Extracting 142 sequences from chr22
# 	Extracting 283 sequences from chr3
# 	Extracting 195 sequences from chr4
# 	Extracting 228 sequences from chr5
# 	Extracting 296 sequences from chr6
# 	Extracting 278 sequences from chr7
# 	Extracting 200 sequences from chr8
# 	Extracting 235 sequences from chr9
# 	Extracting 124 sequences from chrX
#
#
# 	Reading input files...
# 	5750 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaab
# 	Genome = /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
# 	Output Directory = 15-motifscan/aaaab
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 5768
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 5768
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 20 (avg size of targets)
# 	Background files for 20 bp fragments found.
# 	Custom genome sequence directory: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
#
# 	Extracting sequences from file: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa
# 	Looking for peak sequences in a single file (/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa)
# 	Extracting 561 sequences from chr1
# 	Extracting 204 sequences from chr10
# 	Extracting 302 sequences from chr11
# 	Extracting 304 sequences from chr12
# 	Extracting 96 sequences from chr13
# 	Extracting 218 sequences from chr14
# 	Extracting 153 sequences from chr15
# 	Extracting 271 sequences from chr16
# 	Extracting 416 sequences from chr17
# 	Extracting 77 sequences from chr18
# 	Extracting 609 sequences from chr19
# 	Extracting 346 sequences from chr2
# 	Extracting 151 sequences from chr20
# 	Extracting 126 sequences from chr21
# 	Extracting 139 sequences from chr22
# 	Extracting 275 sequences from chr3
# 	Extracting 187 sequences from chr4
# 	Extracting 215 sequences from chr5
# 	Extracting 281 sequences from chr6
# 	Extracting 274 sequences from chr7
# 	Extracting 192 sequences from chr8
# 	Extracting 248 sequences from chr9
# 	Extracting 94 sequences from chrX
#
#
# 	Reading input files...
# 	5739 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# ...
# 	Extracting 1070 sequences from chr9
# 	Extracting 560 sequences from chrX
#
#
# 	Reading input files...
# 	24970 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaad
# 	Genome = /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
# 	Output Directory = 15-motifscan/aaaad
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 24997
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 24997
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 19 (avg size of targets)
# 	Background files for 19 bp fragments found.
# 	Custom genome sequence directory: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
#
# 	Extracting sequences from file: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa
# 	Looking for peak sequences in a single file (/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa)
# 	Extracting 2554 sequences from chr1
# 	Extracting 1087 sequences from chr10
# 	Extracting 1271 sequences from chr11
# 	Extracting 1294 sequences from chr12
# 	Extracting 449 sequences from chr13
# 	Extracting 859 sequences from chr14
# 	Extracting 846 sequences from chr15
# 	Extracting 1075 sequences from chr16
# 	Extracting 1635 sequences from chr17
# 	Extracting 405 sequences from chr18
# 	Extracting 1622 sequences from chr19
# 	Extracting 1717 sequences from chr2
# 	Extracting 763 sequences from chr20
# 	Extracting 379 sequences from chr21
# 	Extracting 632 sequences from chr22
# 	Extracting 1474 sequences from chr3
# 	Extracting 856 sequences from chr4
# 	Extracting 1034 sequences from chr5
# 	Extracting 1411 sequences from chr6
# 	Extracting 1123 sequences from chr7
# 	Extracting 910 sequences from chr8
# 	Extracting 999 sequences from chr9
# 	Extracting 562 sequences from chrX
# 	Extracting 1 sequences from chrY
#
#
# 	Reading input files...
# 	24958 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaaa
# 	Genome = /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
# 	Output Directory = 15-motifscan/aaaaa
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 25001
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 25001
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 20 (avg size of targets)
# 	Background files for 20 bp fragments found.
# 	Custom genome sequence directory: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome
#
# 	Extracting sequences from file: /mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa
# 	Looking for peak sequences in a single file (/mnt/iusers01/fatpou01/bmh01/msc-healthdatasci-2023-2024/z89953zj/models/dictys3k/data/genome/genome.fa)
# 	Extracting 2590 sequences from chr1
# 	Extracting 956 sequences from chr10
# 	Extracting 1327 sequences from chr11
# 	Extracting 1287 sequences from chr12
# 	Extracting 404 sequences from chr13
# 	Extracting 837 sequences from chr14
# 	Extracting 677 sequences from chr15
# 	Extracting 1169 sequences from chr16
# 	Extracting 1825 sequences from chr17
# 	Extracting 355 sequences from chr18
# 	Extracting 2365 sequences from chr19
# 	Extracting 1644 sequences from chr2
# 	Extracting 669 sequences from chr20
# 	Extracting 340 sequences from chr21
# 	Extracting 619 sequences from chr22
# 	Extracting 1370 sequences from chr3
# 	Extracting 773 sequences from chr4
# 	Extracting 1022 sequences from chr5
# 	Extracting 1299 sequences from chr6
# 	Extracting 1167 sequences from chr7
# 	Extracting 804 sequences from chr8
# 	Extracting 1049 sequences from chr9
# 	Extracting 393 sequences from chrX
# 	Extracting 1 sequences from chrY
#
#
# 	Reading input files...
# 	24942 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin binding  tmp_static/Subset3/wellington.tsv.gz tmp_static/Subset3/homer.tsv.gz tmp_static/Subset3/binding.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin tssdist  tmp_static/Subset3/expression.tsv.gz tmp_static/Subset3/wellington.tsv.gz data/gene.bed tmp_static/Subset3/tssdist.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin linking  tmp_static/Subset3/binding.tsv.gz tmp_static/Subset3/tssdist.tsv.gz tmp_static/Subset3/linking.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin binlinking  tmp_static/Subset3/linking.tsv.gz tmp_static/Subset3/binlinking.tsv.gz 20
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network reconstruct --device cpu --nth 4 tmp_static/Subset3/expression.tsv.gz tmp_static/Subset3/binlinking.tsv.gz tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_loss.tsv.gz tmp_static/Subset3/net_stats.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset6/net_iweight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset5/net_iweight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset7/net_iweight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset9/net_iweight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset4/net_iweight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset1/net_weight.tsv.gz tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_weight.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset1/net_iweight.tsv.gz tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset2/net_weight.tsv.gz tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_weight.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset2/net_iweight.tsv.gz tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset3/net_iweight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_inweight.tsv.gz
# make: Nothing to be done for 'cpu'.
# make: Nothing to be done for 'gpu'.
# make: Nothing to be done for 'cpu'.
# mkdir -p output/
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network tofile  data tmp_static data/subsets.txt output/static.h5
# 	Command being timed: "dictys_helper network_inference.sh -j 32 -J 1 static"
# 	User time (seconds): 298030.63
# 	System time (seconds): 11741.26
# 	Percent of CPU this job got: 1650%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 5:12:53
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 3537696
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 2645
# 	Minor (reclaiming a frame) page faults: 821627917
# 	Voluntary context switches: 89403623
# 	Involuntary context switches: 50477882
# 	Swaps: 0
# 	File system inputs: 39619872
# 	File system outputs: 60216152
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %%
# %memit
# Out:
# peak memory: 74.64 MiB, increment: 0.00 MiB
